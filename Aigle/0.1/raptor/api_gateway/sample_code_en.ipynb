# %% [markdown]
# ## RAPTOR API Gateway - Sample Code
#
# - **API Base URL**: http://raptor_open_0_1_api.dhtsolution.com:8012
# - **API Documentation**: http://raptor_open_0_1_api.dhtsolution.com:8012/docs
#
# ## Table of Contents
# 1. Environment Setup and Client Class
# 2. Authentication (Registration, Login)
# 3. Search Features (Video, Audio, Document, Image, Unified Search)
# 4. File Upload (Single, Batch, Upload-and-Analyze)
# 5. Asset Management (List Versions, Download, Archive, Delete)
# 6. Data Processing (Process Files, Cache Queries)
# 7. Chat Features (Send Messages, Manage Memory)
# 8. Health Check
# 9. Complete Workflow Example

# %% [markdown]
# ## Install Dependencies
#
# Execute the following command to install necessary packages:

# %%
# Install requests package
# pip install requests

# %% [markdown]
# ## 1. RaptorAPIClient Client Class
#
# Define complete API client class, encapsulating all API endpoints.

# %%
import requests
import json
from typing import Optional, List, Dict, Any


class RaptorAPIClient:
    """RAPTOR API Gateway Client"""
    
    def __init__(self, base_url: str = "http://raptor_open_0_1_api.dhtsolution.com:8012"):
        self.base_url = base_url
        self.token: Optional[str] = None
    
    def _get_headers(self, include_auth: bool = True) -> Dict[str, str]:
        """Get request headers"""
        headers = {"Content-Type": "application/json"}
        if include_auth and self.token:
            headers["Authorization"] = f"Bearer {self.token}"
        return headers
    
    # ==================== Authentication ====================
    
    def register_user(self, username: str, email: str, password: str) -> Dict[str, Any]:
        """Register New User"""
        url = f"{self.base_url}/api/v1/auth/register"
        payload = {"username": username, "email": email, "password": password}
        response = requests.post(url, json=payload)
        response.raise_for_status()
        return response.json()
    
    def login(self, username: str, password: str) -> str:
        """Login and get JWT token"""
        url = f"{self.base_url}/api/v1/auth/login"
        data = {"username": username, "password": password}
        response = requests.post(url, data=data)
        response.raise_for_status()
        result = response.json()
        self.token = result.get("access_token")
        return self.token
    
    # ==================== Search ====================
    
    def video_search(self, query_text: str, embedding_type: str = "text",
                    filename: Optional[List[str]] = None, speaker: Optional[List[str]] = None,
                    limit: int = 5) -> Dict[str, Any]:
        """Video similarity search"""
        url = f"{self.base_url}/api/v1/search/video_search"
        payload = {"query_text": query_text, "embedding_type": embedding_type, "limit": limit}
        if filename:
            payload["filename"] = filename
        if speaker:
            payload["speaker"] = speaker
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def audio_search(self, query_text: str, embedding_type: str = "text",
                    filename: Optional[List[str]] = None, speaker: Optional[List[str]] = None,
                    limit: int = 5) -> Dict[str, Any]:
        """Audio similarity search"""
        url = f"{self.base_url}/api/v1/search/audio_search"
        payload = {"query_text": query_text, "embedding_type": embedding_type, "limit": limit}
        if filename:
            payload["filename"] = filename
        if speaker:
            payload["speaker"] = speaker
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def document_search(self, query_text: str, embedding_type: str = "text",
                       filename: Optional[List[str]] = None, source: Optional[str] = None,
                       limit: int = 5) -> Dict[str, Any]:
        """Document similarity search"""
        url = f"{self.base_url}/api/v1/search/document_search"
        payload = {"query_text": query_text, "embedding_type": embedding_type, "limit": limit}
        if filename:
            payload["filename"] = filename
        if source:
            payload["source"] = source
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def image_search(self, query_text: str, embedding_type: str = "text",
                    filename: Optional[List[str]] = None, source: Optional[str] = None,
                    limit: int = 5) -> Dict[str, Any]:
        """Image similarity search"""
        url = f"{self.base_url}/api/v1/search/image_search"
        payload = {"query_text": query_text, "embedding_type": embedding_type, "limit": limit}
        if filename:
            payload["filename"] = filename
        if source:
            payload["source"] = source
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def unified_search(self, query_text: str, embedding_type: str = "text",
                      filters: Optional[Dict[str, Dict]] = None, limit_per_collection: int = 5,
                      global_limit: Optional[int] = None, score_threshold: Optional[float] = None) -> Dict[str, Any]:
        """Unified cross-collection search"""
        url = f"{self.base_url}/api/v1/search/unified_search"
        payload = {"query_text": query_text, "embedding_type": embedding_type, "limit_per_collection": limit_per_collection}
        if filters:
            payload["filters"] = filters
        if global_limit:
            payload["global_limit"] = global_limit
        if score_threshold is not None:
            payload["score_threshold"] = score_threshold
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    # ==================== File Upload ====================
    
    def upload_file(self, file_path: str, archive_ttl: int = 30, destroy_ttl: int = 30) -> Dict[str, Any]:
        """Upload Single File"""
        url = f"{self.base_url}/api/v1/asset/fileupload"
        with open(file_path, 'rb') as f:
            files = {'primary_file': f}
            data = {'archive_ttl': archive_ttl, 'destroy_ttl': destroy_ttl}
            headers = {"Authorization": f"Bearer {self.token}"} if self.token else {}
            response = requests.post(url, files=files, data=data, headers=headers)
        response.raise_for_status()
        return response.json()
    
    def upload_files_batch(self, file_paths: List[str], archive_ttl: int = 30,
                          destroy_ttl: int = 30, concurrency: int = 4) -> Dict[str, Any]:
        """Batch Upload Multiple Files"""
        url = f"{self.base_url}/api/v1/asset/fileupload_batch"
        files = []
        try:
            for file_path in file_paths:
                files.append(('primary_files', open(file_path, 'rb')))
            data = {'archive_ttl': archive_ttl, 'destroy_ttl': destroy_ttl, 'concurrency': concurrency}
            headers = {"Authorization": f"Bearer {self.token}"} if self.token else {}
            response = requests.post(url, files=files, data=data, headers=headers)
            response.raise_for_status()
            return response.json()
        finally:
            for _, file_obj in files:
                file_obj.close()
    
    def upload_file_with_analysis(self, file_path: str, processing_mode: str = "default",
                                  archive_ttl: int = 30, destroy_ttl: int = 30) -> Dict[str, Any]:
        """Upload File with Automatic Analysis"""
        url = f"{self.base_url}/api/v1/asset/fileupload_analysis"
        with open(file_path, 'rb') as f:
            files = {'primary_file': f}
            data = {'processing_mode': processing_mode, 'archive_ttl': archive_ttl, 'destroy_ttl': destroy_ttl}
            headers = {"Authorization": f"Bearer {self.token}"} if self.token else {}
            response = requests.post(url, files=files, data=data, headers=headers)
        response.raise_for_status()
        return response.json()
    
    def upload_files_batch_with_analysis(self, file_paths: List[str], processing_mode: str = "default",
                                        archive_ttl: int = 30, destroy_ttl: int = 30,
                                        concurrency: int = 4) -> Dict[str, Any]:
        """Batch upload with analysis"""
        url = f"{self.base_url}/api/v1/asset/fileupload_analysis_batch"
        files = []
        try:
            for file_path in file_paths:
                files.append(('primary_files', open(file_path, 'rb')))
            data = {'processing_mode': processing_mode, 'archive_ttl': archive_ttl,
                   'destroy_ttl': destroy_ttl, 'concurrency': concurrency}
            headers = {"Authorization": f"Bearer {self.token}"} if self.token else {}
            response = requests.post(url, files=files, data=data, headers=headers)
            response.raise_for_status()
            return response.json()
        finally:
            for _, file_obj in files:
                file_obj.close()
    
    # ==================== Asset Management ====================
    
    def list_file_versions(self, asset_path: str, filename: str) -> Dict[str, Any]:
        """List all versions of a file"""
        url = f"{self.base_url}/api/v1/asset/fileversions"
        params = {"asset_path": asset_path, "filename": filename}
        response = requests.get(url, params=params, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def download_asset(self, asset_path: str, version_id: str, return_file_content: bool = True) -> Any:
        """Download Asset"""
        url = f"{self.base_url}/api/v1/asset/filedownload"
        params = {"asset_path": asset_path, "version_id": version_id, "return_file_content": return_file_content}
        response = requests.get(url, params=params, headers=self._get_headers())
        response.raise_for_status()
        return response.content if return_file_content else response.json()
    
    def archive_asset(self, asset_path: str, version_id: str) -> Dict[str, Any]:
        """Archive Asset"""
        url = f"{self.base_url}/api/v1/asset/filearchive"
        params = {"asset_path": asset_path, "version_id": version_id}
        response = requests.post(url, params=params, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def delete_asset(self, asset_path: str, version_id: str) -> Dict[str, Any]:
        """Delete archived asset"""
        url = f"{self.base_url}/api/v1/asset/delfile"
        params = {"asset_path": asset_path, "version_id": version_id}
        response = requests.post(url, params=params, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    # ==================== Processing ====================
    
    def process_file(self, upload_result: Dict[str, Any]) -> Dict[str, Any]:
        """Process Uploaded File"""
        url = f"{self.base_url}/api/v1/processing/process-file"
        payload = {"upload_result": upload_result}
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def get_cached_value(self, m_type: str, key: str) -> Dict[str, Any]:
        """Get cache value from Redis"""
        url = f"{self.base_url}/api/v1/processing/processing/cache/{m_type}/{key}"
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    
    def get_all_cache(self) -> Dict[str, Any]:
        """Get all Redis cache"""
        url = f"{self.base_url}/api/v1/processing/cache/all"
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    
    # ==================== Chat ====================
    
    def send_chat(self, user_id: str, message: str, search_results: Optional[List[Dict]] = None) -> Dict[str, Any]:
        """Send Chat Message"""
        url = f"{self.base_url}/api/v1/chat/chat"
        payload = {"user_id": user_id, "message": message}
        if search_results:
            payload["search_results"] = search_results
        response = requests.post(url, json=payload, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def get_chat_memory(self, user_id: str) -> Dict[str, Any]:
        """Get user chat memory"""
        url = f"{self.base_url}/api/v1/chat/memory/{user_id}"
        response = requests.get(url, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    def clear_chat_memory(self, user_id: str) -> Dict[str, Any]:
        """Clear user chat memory"""
        url = f"{self.base_url}/api/v1/chat/memory/{user_id}"
        response = requests.delete(url, headers=self._get_headers())
        response.raise_for_status()
        return response.json()
    
    # ==================== Health ====================
    
    def health_check(self) -> Dict[str, Any]:
        """Health Check"""
        url = f"{self.base_url}/health"
        response = requests.get(url)
        response.raise_for_status()
        return response.json()


print("✓ RaptorAPIClient class defined successfully")
# Out:
# ✓ RaptorAPIClient 類別已定義完成

# %% [markdown]
# ## 2. Initialize Client

# %%
# Initialize Client
client = RaptorAPIClient()
print(f"API Base URL: {client.base_url}")
# Out:
# API Base URL: http://raptor_open_0_1_api.dhtsolution.com:8012

# %% [markdown]
# ## 3. 認證功能
#
# ### 3.1 Register New User

# %%
# Register New User（首次使用時執行）
try:
    result = client.register_user(
        username="test_user1",
        email="test@example.com",
        password="secure_password"
    )
    print("Registration successful:", json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Registration failed: {e}")
    # If user already exists, this is normal
# Out:
# 註冊成功: {
#   "username": "test_user1"
# }

# %% [markdown]
# ### 3.2 Login to Get Token

# %%
# Login to get JWT Token
try:
    token = client.login(username="test_user1", password="secure_password")
    print(f"✓ Login successful")
    print(f"Token (first 30 characters): {token[:30]}...")
except Exception as e:
    print(f"✗ Login failed: {e}")
# Out:
# ✓ 登入成功
# Token (前 30 字元): eyJhbGciOiJIUzI1NiIsInR5cCI6Ik...

# %% [markdown]
# ## 4. 搜尋功能
#
# ### 4.1 Video Search

# %%
# Video Search
try:
    result = client.video_search(
        query_text="machine learning",
        embedding_type="text",
        # filename=["MV.mp4"],     # Optional parameter
        # speaker=["SPEAKER_00"],  # Optional parameter
        limit=5
    )
    print("Video Search結果:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Search failed: {e}")
# Out:
# 影片搜尋結果:
# {
#   "success": true,
#   "total": 5,
#   "results": [
#     {
#       "score": 0.49837154,
#       "id": "0e46744e-23ef-4775-8f9c-266f8c0aa19d",
#       "payload": {
#         "audio_id": "YTtest1.mp4_chunk_4",
#         "text": "它是一種開發方法論要求在編寫代碼之前先編寫測試代碼定義預期行爲像這樣就可以防止AI產生幻覺因爲AI喜歡自己腦補好下面我們看一下SpyKit它的核心優勢首先是多AI編程助手支持它支持Cloud CodeGitHub Copilot",
#         "filename": "YTtest1.mp4",
#         "chunk_index": 4,
#         "start_time": "96.64",
#         "end_time": "115.135",
#         "speaker": "SPEAKER_00",
#         "type": "videos",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T18:26:45.827703",
#         "embedding_type": "text",
#         "asset_path": "video/mp4/YTtest1",
#         "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.4948697,
#       "id": "840f4b86-0540-45aa-9173-358d173ece57",
#       "payload": {
#         "audio_id": "YTtest1.mp4_chunk_5",
#         "text": "Gemini、CLI、Cursor等AI編程助手大家就可以在自己擅長的AI編程助手裏來使用SPACKIT它通過結構化的模板約束大模型輸出確保規範的完整性可測試性和架構一致性防止過度工程",
#         "filename": "YTtest1.mp4",
#         "chunk_index": 5,
#         "start_time": "115.135",
#         "end_time": "131.032",
#         "speaker": "SPEAKER_00",
#         "type": "videos",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T18:26:45.827703",
#         "embedding_type": "text",
#         "asset_path": "video/mp4/YTtest1",
#         "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.48948818,
#       "id": "edee60e0-28eb-4d92-a322-729691a49042",
#       "payload": {
#         "audio_id": "YTtest1.mp4_chunk_3",
#         "text": "也就是規格是源頭代碼是表達最關鍵的是SPACit把測試驅動開發寫進了默認流程我們只需要用命令就可以一鍵確實化項目建立模板和執行工作流而且支持在大部分AI編程制手裏通過命令去使用本期視頻我會把SPACit的項目從理念到實戰完整的講解並演示在演示之前我們先看一下SPACit它支持的測試驅動開發測試驅動開發簡稱TDD",
#         "filename": "YTtest1.mp4",
#         "chunk_index": 3,
#         "start_time": "67.649",
#         "end_time": "96.64",
#         "speaker": "SPEAKER_00",
#         "type": "videos",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T18:26:45.827703",
#         "embedding_type": "text",
#         "asset_path": "video/mp4/YTtest1",
#         "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.47949466,
#       "id": "17913ba6-67ef-4715-8af0-68bce7ef32b3",
#       "payload": {
#         "audio_id": "YTtest1.mp4_chunk_0",
#         "text": "最近很多粉絲私信讓我講講GitHub上開源的SpecKey項目經過我這段時間的測試和使用發現這個項目比我們之前介紹的SpecWorkflow MCP效果要更好我們只需要用到幾個命令就可以把需求寫成可執行的規範再讓AI自動產出計劃任務最後按任務寫代碼並完成項目開發而且這個項目上手很快幾分鐘就能跑通",
#         "filename": "YTtest1.mp4",
#         "chunk_index": 0,
#         "start_time": "5.903",
#         "end_time": "29.275",
#         "speaker": "SPEAKER_00",
#         "type": "videos",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T18:26:45.827703",
#         "embedding_type": "text",
#         "asset_path": "video/mp4/YTtest1",
#         "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.47888294,
#       "id": "2b82592b-b418-4b4a-a7ca-7e4c589627fc",
#       "payload": {
#         "audio_id": "YTtest1.mp4_chunk_9",
#         "text": "這裏就會讓我們選擇在哪個AI編程制手中去使用它這裏支持Copilot,Cloud,Gemini,Cursor還有Codex還有Kilo Code,Ru Code等AI編程制手然後我這裏就選擇Cloud Code像Cursor用戶這裏就可以選擇Cursor像Codex用戶這裏就可以選擇Codex",
#         "filename": "YTtest1.mp4",
#         "chunk_index": 9,
#         "start_time": "200.388",
#         "end_time": "218.123",
#         "speaker": "SPEAKER_00",
#         "type": "videos",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T18:26:45.827703",
#         "embedding_type": "text",
#         "asset_path": "video/mp4/YTtest1",
#         "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#         "status": "active"
#       }
#     }
#   ]
# }

# %% [markdown]
# ### 4.2 Audio Search

# %%
# Audio Search
try:
    result = client.audio_search(
        query_text="artificial intelligence",
        embedding_type="text",
        limit=5
    )
    print("Audio Search結果:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Search failed: {e}")
# Out:
# 音訊搜尋結果:
# {
#   "success": true,
#   "total": 5,
#   "results": [
#     {
#       "score": 0.5671233,
#       "id": "9cf632a8-0cf8-4dbb-a9fa-f8f780c4fa73",
#       "payload": {
#         "audio_id": "AI02_chunk_2",
#         "text": "OpenAI最新的O3模型被譽為目前最聰明最強大的人工智慧它幾乎無所不能連最複雜的問題都能迎刃而解但也正因如此它展現出前所未有的自我意識甚至出現抗命行為測驗是一個控制性的實驗設定是足夠無害的他們要求AI模型解決數學問題",
#         "filename": "AI02.wav",
#         "chunk_index": 2,
#         "start_time": "35.283",
#         "end_time": "58.672",
#         "speaker": "SPEAKER_03",
#         "type": "audios",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T09:01:16.246019+00:00",
#         "embedding_type": "text",
#         "asset_path": "audio/x-wav/AI02",
#         "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.51834726,
#       "id": "72d141e3-72ef-4c87-b4e4-e78957e68cfd",
#       "payload": {
#         "audio_id": "AI02_chunk_6",
#         "text": "當AI開始思考判斷甚至反制人類是否還能牢牢握住主控權這不再是科幻情節而是一個正快速逼近的現實挑戰",
#         "filename": "AI02.wav",
#         "chunk_index": 6,
#         "start_time": "114.562",
#         "end_time": "132.753",
#         "speaker": "SPEAKER_03",
#         "type": "audios",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T09:01:16.246252+00:00",
#         "embedding_type": "text",
#         "asset_path": "audio/x-wav/AI02",
#         "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.5106939,
#       "id": "6094f72f-0cf6-4035-a181-70b498b047ee",
#       "payload": {
#         "audio_id": "AI02_chunk_0",
#         "text": "大家現在都在看AI但是AI近年快速發展隨著技術突飛猛進風險也隨之浮現譬如說OpenAI旗下的最新語言模型在最新的實驗當中不但它自己拒絕關機甚至還主動破解程式修改指令因此也再一次引發外界對於AI自主性的風險高度關注",
#         "filename": "AI02.wav",
#         "chunk_index": 0,
#         "start_time": "0.031",
#         "end_time": "22.222",
#         "speaker": "SPEAKER_01",
#         "type": "audios",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T09:01:16.245865+00:00",
#         "embedding_type": "text",
#         "asset_path": "audio/x-wav/AI02",
#         "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.49549806,
#       "id": "996e0e59-ab0e-4b39-8c79-74fcf6134cf8",
#       "payload": {
#         "audio_id": "AI02_chunk_4",
#         "text": "理論上 應該就是這樣但O3沒有關閉AI沒有遵循規則它重寫了測試結果顯示在一百次受控實驗中O3模型有七次成功抗命類似的情況也發生在競爭對手Anthropic的語言模型Claude Opus 4上Anthropic設定了一個假的模式來測試這個模型在這個模式上Opus AI模型正在在偽公司工作",
#         "filename": "AI02.wav",
#         "chunk_index": 4,
#         "start_time": "67.548",
#         "end_time": "95.324",
#         "speaker": "SPEAKER_03",
#         "type": "audios",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T09:01:16.246150+00:00",
#         "embedding_type": "text",
#         "asset_path": "audio/x-wav/AI02",
#         "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.4849242,
#       "id": "45bb0d9c-c2c7-4526-b959-1f479b996364",
#       "payload": {
#         "audio_id": "AI02_chunk_5",
#         "text": "It learns that it is getting replacedThe AI model is getting replacedIt finds outSo what does the model doIt starts combing through emailsIt learns that the engineer responsible for it is having an affairSo Opus makes a choiceIt chooses survival over ethics",
#         "filename": "AI02.wav",
#         "chunk_index": 5,
#         "start_time": "95.965",
#         "end_time": "113.802",
#         "speaker": "SPEAKER_02",
#         "type": "audios",
#         "audio_labels": [
#           "Speech"
#         ],
#         "upload_time": "2025-10-27T09:01:16.246203+00:00",
#         "embedding_type": "text",
#         "asset_path": "audio/x-wav/AI02",
#         "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#         "status": "active"
#       }
#     }
#   ]
# }

# %% [markdown]
# ### 4.3 Document Search

# %%
# Document Search
try:
    result = client.document_search(
        query_text="financial report",
        embedding_type="text",
        # source="csv",     # Optional parameter
        limit=5
    )
    print("Document Search結果:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Search failed: {e}")
# Out:
# 文件搜尋結果:
# {
#   "success": true,
#   "total": 5,
#   "results": [
#     {
#       "score": 0.5187794,
#       "id": "d0755d26-b656-4010-ade8-454090d3647a",
#       "payload": {
#         "document_id": "公司變更登記表_chunk_1",
#         "type": "documents",
#         "text": "<TABLE>\n| 01 | A401010 |  |\n| --- | --- | --- |\n| 02 | A401020 |  |\n| 03 | A401040 |  |\n|  | C103050 | 04 |\n|  | C199990 | 05 |\n| 06 | C201010 |  |\n| 07 | F101040 |  |\n|  | F101990 | 08 |\n| 09 | F102170 |  |\n| 10 | F103010 |  |\n| 11 |  |  |\n| 12 | F201010 |  |\n| 13 | F201020 |  |\n| 14 | F201990 |  |\n| 15 | F202010 |  |\n|  | F203010 | 16 |\n| 17 | F399040 |  |\n| 18 | F401010 |  |\n| 19 | J101040 |  |\n|  | J799990 | 20 |\n|  | ZZ99999 | 21 |\n</TABLE>\n\n<IMAGE>\n印章上有「某某商業發展公司登記表專用章」，以及日期「113.8.19」。\n</IMAGE>\n\n19\n\n7j 1302\n\n<IMAGE>\n這是一份公司董事、監察人或其他負責人名單的公務記載蓋章確認文件。\n</IMAGE>\n\n5\n\n02\n\n38, 250, 000\n\n03\n\n8, 166, 667\n\n05\n\nW\n\n=\n\n1 ~ 2\n\n01\n\n3\n\n02\n\n03\n\n19\n\n113. 8 .\n\n7j 1302",
#         "filename": "公司變更登記表.pdf",
#         "source": "pdf",
#         "chunk_index": 1,
#         "page_numbers": [
#           4,
#           5
#         ],
#         "element_types": [
#           "image",
#           "table",
#           "text"
#         ],
#         "char_count": 661,
#         "upload_time": "2025-11-06T18:40:11.402139",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/公司變更登記表",
#         "version_id": "89513d96927dab25fd6c6f9b6f3273770e3c66cd73deb68460ac3787789441b2",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.50054526,
#       "id": "b7ac05fe-21b3-420e-8936-d642b0311820",
#       "payload": {
#         "document_id": "第一商業銀行客戶身分資料審查問答集2025.5_chunk_2",
#         "type": "documents",
#         "text": "如果貴公司 / 團體 / 組織的名稱、統一編號、法定代理人或代表人、高階管 理人員或實質受益人等資訊有變更，敬請負責人持正本證明文件 ( 身分證、 變更事項登記表、公司章程、股東名冊等 ) 及原留印鑑親臨本行各分行辦理。\n\n7. 我如果沒有完成資料檢視，會有什麼影響 ?\n\n為保障客戶權益並避免帳戶被盜用的風險，倘未於指定期限完成客戶資料更新， 本行將會暫停您目前使用的自動化交易服務 ( 例如部分網路銀行、行動銀行或 語音銀行的服務 ) 以維護您帳戶交易之安全，但不會影響您既有的 ATM 及約定 代繳公共事業費率轉帳服務，直至您日後完成資料確認後，才會再重啟相關功 能服務。\n\n8. 如果我存款帳戶餘額很低，已無使用之必要性，但沒空去銀行確認 資料應怎麼處理 ?\n\n如果您的存款帳戶確認已無使用之必要性，建議您可以簡便方式結清帳戶。\n\n郵寄 : 若您的台幣或外幣帳戶存款餘額低於新台幣十萬元 ( 或等值外幣 ) 以 下，可於本行官方網站下載「新臺幣 / 外匯存款帳戶結清銷戶申請書 ( 郵寄 專用 ) 」 ( 路徑為 : 首頁 / 表格下載 / 結清銷戶申請書 〈郵寄專用〉 【 PDF 表格】 )\n\n網路 : 若您的台幣或外幣帳戶存款餘額低於新台幣五萬元 ( 或等值外幣 ) 以 下，可透過網路線上結清。\n\n9. 如果我還有關於客戶身分資料審查方面的其他問題可以向誰諮詢 ?",
#         "filename": "第一商業銀行客戶身分資料審查問答集2025.5.pdf",
#         "source": "pdf",
#         "chunk_index": 2,
#         "page_numbers": [
#           2
#         ],
#         "element_types": [
#           "text"
#         ],
#         "char_count": 590,
#         "upload_time": "2025-10-27T18:06:54.505917",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/第一商業銀行客戶身分資料審查問答集2025.5",
#         "version_id": "ceaa97a2a72dd618e3151305d4158a394c442b9fac80ba55ce989934319e0dbc",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.4832966,
#       "id": "c06f173b-3c02-43a3-be01-c95630b73a59",
#       "payload": {
#         "document_id": "公司變更登記表_chunk_0",
#         "type": "documents",
#         "text": "E*\n\n<IMAGE>\n這張圖片展示了兩列印章，每列上方有「公司印章」和「代表公司負責人印章」的標籤。\n</IMAGE>\n\nW\n\n<IMAGE>\n這是一份公司的預查編號、統一編號和聯絡電話的表格。\n</IMAGE>\n\n#TY\n\n#TY\n\n# x\n\nbk>\n\n100, 000, 000 A4\n\n+\n\n20\n\n113 4 2 A 19 &\n\n113 8 19\n\nJ )\n\nFj 1302 144\n\n1071108 /24\n\n<TABLE>\n| #Tv |\n| --- |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n| #Tv |\n</TABLE>\n\n<IMAGE>\n圖片內容是一個印章，日期為1981年11月19日，上面寫有「經濟部商業發展署公司登記表專用章」。\n</IMAGE>\n\n19\n\n113 8",
#         "filename": "公司變更登記表.pdf",
#         "source": "pdf",
#         "chunk_index": 0,
#         "page_numbers": [
#           1,
#           2,
#           3
#         ],
#         "element_types": [
#           "image",
#           "text",
#           "table"
#         ],
#         "char_count": 449,
#         "upload_time": "2025-11-06T18:40:11.402139",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/公司變更登記表",
#         "version_id": "89513d96927dab25fd6c6f9b6f3273770e3c66cd73deb68460ac3787789441b2",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.47360772,
#       "id": "f8889844-9023-4185-8b01-05125fd3dd6f",
#       "payload": {
#         "document_id": "裕德軟體架構設計文件_0808_chunk_6",
#         "type": "documents",
#         "text": "<IMAGE>\n這張圖片展示了一個學校資訊儀表板，包括學生人數、老師人數、課堂使用率、學生到校情況，以及學生出勤率和成績分佈的圖表。\n</IMAGE>\n\n2025/8/8\n\n1,842\n\n128\n\n96.49\n\n24/8\n\n\"a\n\n2.06\n\n72\n\n35\n\na5\n\n486\n\n97,19\n\n502\n\n222\n\n476\n\n95.996\n\n378\n\n4.2 系統管理 介 面\n\nØ 人 物 角色設定\n\nn\n\n功能解說：提供管理者設定 與 修改人 物 角色\n\nn UI 畫面：\n\n<IMAGE>\n系統管理介面顯示角色設定與權限分配。\n</IMAGE>\n\n12\n\n85\n\n軟體架構設計文件 / 版本 v1.0/  p. 14\n\n<IMAGE>\n這是一個角色權限設置界面，顯示教師角色的使用功能權限，包括功能1、功能2、功能3和功能4的選擇。\n</IMAGE>\n\nn 按鈕解說：\n\n【新增角色】管理者可以在角色權限 詳細 設定畫面中設定訊息後儲存權\n\n限設定\n\n【編輯】 點 選後會顯示角色權限 詳細 設定畫面修改權限內容\n\n【使用功能權限】 多 選 方式去 選 擇 該角色能使用的功能\n\n【儲存權限設定】將修改或新增內容儲存\n\nØ 知識庫 權限設定\n\nn 功能解說：提供管理者設定 知識庫詳細 權限 與 使用者能使用的 知識庫 權限功能\n\nn UI 畫面：\n\n軟體架構設計文件 / 版本 v1.0/  p. 15",
#         "filename": "裕德軟體架構設計文件_0808.pdf",
#         "source": "pdf",
#         "chunk_index": 6,
#         "page_numbers": [
#           13,
#           14,
#           15
#         ],
#         "element_types": [
#           "image",
#           "text"
#         ],
#         "char_count": 603,
#         "upload_time": "2025-11-05T16:25:38.815074",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/裕德軟體架構設計文件_0808",
#         "version_id": "a0006b8c3ee1927370971520ffadbdaaa5c4a7bea333ed47829597297bb3422b",
#         "status": "active"
#       }
#     },
#     {
#       "score": 0.4730616,
#       "id": "5da487fd-c4cd-4b2d-ad98-4fab5a906986",
#       "payload": {
#         "document_id": "tmpci3nryq3_chunk_37",
#         "type": "documents",
#         "text": "# Content Management API POST /api/v1/content/upload GET /api/v1/content/{id} PUT /api/v1/content/{id}\n\nDELETE /api/v1/content/{id}\n\n45\n\n<IMAGE>\n圖片顯示了一個標誌，上面寫著「DHT Solution 迪衡科技」。\n</IMAGE>\n\n10. Performance and Scalability\n\n10.1 MCP Server Performance Architecture\n\n10.1.1 Task Orchestration Performance\n\n```psudo-python class PerformanceOrchestrator: def __init__(self): self.task_scheduler = TaskScheduler() self.resource_optimizer = ResourceOptimizer() self.load_balancer = LoadBalancer() self.performance_monitor = PerformanceMonitor() async def optimize_task_execution(self, tasks: List[Task]) > Dict: # Analyze task dependencies and resource requirements dependency_graph = await self.task_scheduler.build_dependency_graph(tasks) # Optimize resource allocation allocation_plan = await self.resource_optimizer.optimize_allocation( tasks, dependency_graph ) # Balance load across workers execution_plan = await self.load_balancer.create_execution_plan( allocation_plan ) return { 'dependency_graph': dependency_graph, 'allocation_plan': allocation_plan, 'execution_plan': execution_plan, 'estimated_completion_time': execution_plan.total_time }\n\n```\n\n46",
#         "filename": "tmpci3nryq3.pdf",
#         "source": "pdf",
#         "chunk_index": 37,
#         "page_numbers": [
#           45,
#           46
#         ],
#         "element_types": [
#           "image",
#           "text"
#         ],
#         "char_count": 1156,
#         "upload_time": "2025-11-06T16:32:48.140830",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/tmpci3nryq3",
#         "version_id": "224b759ef7322fb7bffb248c146896396358354bb500ac3dc46b1923cf64b572",
#         "status": "active"
#       }
#     }
#   ]
# }

# %% [markdown]
# ### 4.4 Image Search

# %%
# Image Search
try:
    result = client.image_search(
        query_text="landscape photo",
        embedding_type="summary", 
        # source="jpg",     # Optional parameter
        limit=5
    )
    print("Image Search結果:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Search failed: {e}")
# Out:
# 圖片搜尋結果:
# {
#   "success": true,
#   "total": 5,
#   "results": [
#     {
#       "score": 0.6062982,
#       "id": "b76cae48-15e8-4288-a2e2-7096bcf2106d",
#       "payload": {
#         "filename": "test.jpg",
#         "type": "images",
#         "upload_time": "2025-10-28T09:02:27.336838+00:00",
#         "embedding_type": "summary",
#         "asset_path": "image/jpg/test",
#         "version_id": "9690223a3678339b984027ba7f7c511b207d700bb0a284fa091c392e6abd38be",
#         "status": "active",
#         "summary": "這張圖片展現了一片明亮開闊的草地，草叢呈現出鮮豔的綠色，給人清新、平和的感覺。草地上有一棵茂密的綠色樹木，樹木直立於草地中央，樹冠廣闊且飽滿。背景中是輪廓和緩的草甸，延伸至視野的盡頭。\n\n天空部分是湛藍的顏色，伴隨著白色的雲朵，使畫面更顯得寬闊和通透。整體場景透露出寧靜與自然的美麗，是一個適合放鬆與享受自然風光的地方。"
#       }
#     },
#     {
#       "score": 0.4727788,
#       "id": "910249f1-555c-473b-96be-7615dc642290",
#       "payload": {
#         "filename": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg",
#         "type": "images",
#         "upload_time": "2025-10-31T03:15:50.698020+00:00",
#         "embedding_type": "summary",
#         "asset_path": "image/jpg/Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_",
#         "version_id": "378787f28e90ac6dae5e7dedbcfaee4965d5e053f6a247acdb208f4f0c35f63b",
#         "status": "active",
#         "summary": "這張圖片捕捉到一場籃球比賽的精彩瞬間。畫面中有兩支隊伍，一隊穿著綠色和白色相間的球衣，另一隊則穿著酒紅色和金色的球衣。綠色球隊的球員正試圖將籃球投入籃筐，而酒紅色球隊的兩員正跳起來封蓋投籃。畫面上有多名球員和一名裁判。\n\n球員們的球衣上有明顯的號碼和姓名。綠色球隊的球員分別為44號的William以及11號的Prichard，還有45號的Valentines。酒紅色球隊則有32號的球員以及3號的球員。背景中可以看到觀眾席上坐滿了觀眾，everyone 都在關注比賽的進行。\n\n場地的地板是木質的，中場位置有大學標誌性的圖案。籃筐上方掛有美國旗，籃筐旁邊則有UPS的標誌。裁判站在場地的一側，身穿黑白條紋的上衣，密切關注球員的動作。這是一場激烈且動態的比賽場景。"
#       }
#     },
#     {
#       "score": 0.46869487,
#       "id": "02f5513a-47f4-4a02-bd49-55f057262b23",
#       "payload": {
#         "filename": "Faker_2020_interview.jpg",
#         "type": "images",
#         "upload_time": "2025-10-31T03:10:55.545163+00:00",
#         "embedding_type": "summary",
#         "asset_path": "image/jpg/Faker_2020_interview",
#         "version_id": "9d351ca208d14e900e8baec698a726b8ea479a7d42d0baac6719138993d3d1f3",
#         "status": "active",
#         "summary": "這張圖片展示了一位年輕的男子。他戴著圓框眼鏡，留著短髮，面帶微笑。他穿著一件黑色T恤，上面有「SKT 5GX」的標誌。他的左臂上戴着一個黑色袖章，袖章上有一個卡通鯊魚的圖案，以及「鬥魚 DOUTHU.COM」的標誌。他的右手臂前舉，做出「噹啷」的手勢。背景似乎是室內場所，牆壁為深色，有光源照明。整體看起來像在一個活動或聚會上拍攝的照片。"
#       }
#     },
#     {
#       "score": 0.43939745,
#       "id": "0e4a86e4-bd86-4038-abe0-53f8fb75158e",
#       "payload": {
#         "filename": "frame_0119.jpg",
#         "type": "images",
#         "upload_time": "2025-10-28T08:20:02.251609+00:00",
#         "embedding_type": "summary",
#         "asset_path": "image/jpg/frame_0119",
#         "version_id": "614219c19a122582717261245eb72c6e7f5025bf8b85398fd3f0e9f4447a24dd",
#         "status": "active",
#         "summary": "圖片中有兩個旗幟。左邊是中華民國國旗，有紅、白、藍三色。右邊是一面藍色旗幟，上面寫有「國立陽明交通大學」的中英文字樣。\n\n圖片下方的字幕是：「學習歷程造假能錄取醫學系？系辦將開會確認資格」以及「砸車恐嚇 球棒隊出沒！屏幕惡煞持棍棒砸轎車 撧風玻璃全毀」。\n\n圖片左下角顯示時間為12:25:18，以及一些數據和字元，如「0.140」和「34.103」。右上角有「臺視新聞HD」的標識，以及「最新」的標籤。"
#       }
#     },
#     {
#       "score": 0.43752742,
#       "id": "7ab69efe-c44a-4be4-854d-9687e4bb7d5a",
#       "payload": {
#         "filename": "pdf.png",
#         "type": "images",
#         "upload_time": "2025-10-27T10:11:04.957094+00:00",
#         "embedding_type": "summary",
#         "asset_path": "image/png/pdf",
#         "version_id": "740a4ef69199ab850c7b2417c960e002c5e1cab7ea1dc55221bfe8164b3130f8",
#         "status": "active",
#         "summary": "這張圖片宣傳的是「魚水文旅 | 大小港邊經典半日遊」，包含多個項目的地點和活動。以下是圖片中的文字和觀感：\n\n日期：2025年9月10日 上午11:23  \n地點：大小港邊經典·大鯉灣國家風景區\n\n**夕陽海鮮晚宴**  \n- 地點：樓頂上的漁村體驗  \n- 描述：提供在林邊鄉崎峯村的老舊住宅舉辦的海鮮晚宴。這是一個普通建築，但夜晚有著驚人的海洋風景。晚餐包括八菜一鴿一湯及無酒精飲料，提供各種不同季節的菜色。\n\n**午仔魚一夜幹DIY**  \n- 活動：參加午仔魚一夜幹的製作體驗，學習水產養殖知識，製作屬於自己的午仔魚。\n\n圖片中還顯示：\n- 右側上方是一張豐富的海鮮拼盤，包括魚和配菜。\n- 中間偏右是一碗包含蔬菜的湯。\n- 底部有一堆魚，背景是海邊建築。\n\n整體設計以藍白顏色為主，突出海鮮和漁村主題。"
#       }
#     }
#   ]
# }

# %% [markdown]
# ### 4.5 Unified Search (Cross-Collection)

# %%
# Unified search - search multiple collections simultaneously
try:
    result = client.unified_search(
        query_text="machine learning和artificial intelligence",
        embedding_type="text",
        filters={
            "video": {"filename": ["MV.mp4"]},
            "document": {"source": "csv"}
        },
        limit_per_collection=3,
        global_limit=10,
        score_threshold=0.5
    )
    print("Unified search results:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Search failed: {e}")
# Out:
# 統一搜尋結果:
# {
#   "query": "機器學習和人工智慧",
#   "embedding_type": "text",
#   "total_results": 1,
#   "collections_searched": [
#     "video",
#     "audio",
#     "document",
#     "image"
#   ],
#   "results": [
#     {
#       "type": "image",
#       "collection": "image",
#       "score": 0.50083816,
#       "id": "e5b5c1df-72bc-43c3-9ebb-6050e98fad09",
#       "payload": {
#         "document_id": "1140403.png_chunk_0",
#         "type": "images",
#         "text": "AI-Enabled Financial Intelligence Integrated Application System\n\nCTR Module UI\n\nSTR Module UI\n\nETL Pipeline\n\nCentral Database\n\nAI Model\n\nPerformance Dashboard\n\nBack-end Admin",
#         "filename": "1140403.png",
#         "source": "png",
#         "chunk_index": 0,
#         "page_numbers": [
#           1
#         ],
#         "element_types": [
#           "text"
#         ],
#         "char_count": 174,
#         "upload_time": "2025-10-31T05:11:39.917191+00:00",
#         "embedding_type": "text",
#         "asset_path": "image/png/1140403",
#         "version_id": "4de1ef134c260e74fadce12db37367c0fb38a022c14e1ad62b6aec811a012874",
#         "status": "active"
#       }
#     }
#   ],
#   "collection_stats": {
#     "video": {
#       "count": 0,
#       "avg_score": 0
#     },
#     "audio": {
#       "count": 3,
#       "avg_score": 0.47035378333333333
#     },
#     "document": {
#       "count": 0,
#       "avg_score": 0
#     },
#     "image": {
#       "count": 3,
#       "avg_score": 0.47345205333333334
#     }
#   },
#   "execution_time_ms": 2517.56
# }

# %% [markdown]
# ## 5. File Upload
#
# ### 5.1 Upload Single File
#
# **Note**: The following examples require actual file paths. Please modify `file_path` to your file path.

# %%
# Upload Single File（請修改檔案路徑）
try:
    result = client.upload_file(
        file_path="./sample_files/water.pdf",
        archive_ttl=30,
        destroy_ttl=30
    )
    print("Upload successful:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - 請取消註解並提供實際檔案路徑）")
except Exception as e:
    print(f"Upload failed: {e}")
# Out:
# 上傳成功:
# {
#   "asset_path": "document/pdf/water",
#   "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#   "primary_filename": "water.pdf",
#   "associated_filenames": [],
#   "upload_date": "2025-11-14T12:36:26.648940+08:00",
#   "archive_date": "2025-12-14T12:36:26.648940+08:00",
#   "destroy_date": "2026-01-13T12:36:26.648940+08:00",
#   "branch": "admin_space",
#   "status": "active"
# }

# %% [markdown]
# ### 5.2 Batch Upload Multiple Files

# %%
# Batch Upload Multiple Files
try:
    result = client.upload_files_batch(
        file_paths=[
            "./sample_files/water.pdf",
            "./sample_files/AI999.wav",
            "./sample_files/EF25Y01.csv"
        ],
        archive_ttl=30,
        destroy_ttl=30,
        concurrency=4
    )
    print("批次Upload successful:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"批次Upload failed: {e}")

# %% [markdown]
# ### 5.3 Upload File with Automatic Analysis

# %%
# Upload File with Automatic Analysis
try:
    result = client.upload_file_with_analysis(
        file_path="./sample_files/water.pdf",
        processing_mode="default",
        archive_ttl=30,
        destroy_ttl=30
    )
    print("Upload and analysis successful:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Upload analysis failed: {e}")
# Out:
# 上傳並分析成功:
# {
#   "upload_result": {
#     "asset_path": "document/pdf/water",
#     "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#     "primary_filename": "water.pdf",
#     "associated_filenames": [],
#     "upload_date": "2025-11-14T12:36:27",
#     "archive_date": "2025-12-14T12:36:27",
#     "destroy_date": "2026-01-13T12:36:27",
#     "branch": "admin_space",
#     "status": "active"
#   },
#   "processing_result": {
#     "message_id": "a695ab9a-8438-47d8-8793-5305d74f64e0",
#     "correlation_id": "deb52768-7fa9-4375-922f-c36c09ab222d"
#   }
# }

# %% [markdown]
# ## 6. Asset Management
#
# ### 6.1 List File Versions
#
# **Note**: Need to have uploaded files before querying versions.

# %%
# List File Versions
try:
    result = client.list_file_versions(
        asset_path="document/pdf/water",     # Must match the asset_path returned from upload above
        filename="water.pdf"                 # Must match the primary_filename returned from upload above
    )
    print("File version list:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - 需要實際的 asset_path 和 filename）")
except Exception as e:
    print(f"Query failed: {e}")
# Out:
# 檔案版本列表:
# {
#   "versions": [
#     {
#       "key": "document/pdf/water/water.pdf",
#       "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#       "last_modified": "2025-11-14T12:36:27",
#       "url": "http://raptor_open_0_1_api.dhtsolution.com:8343/lakefs/data/g4s52dkggrlc7390brqg/d4bb3ikggrlc7390brr0%2C0unI_EbJo76Q8Frhouep4cra11ZjQG-OI_thpn2iuhc?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=qweasdzxc%2F20251114%2F%22none%22%2Fs3%2Faws4_request&X-Amz-Date=20251114T043847Z&X-Amz-Expires=1200&X-Amz-SignedHeaders=host&response-content-disposition=attachment%3B%20filename%3Dwater.pdf&x-id=GetObject&X-Amz-Signature=4ca0c82c1c5af4423d19a2a30086183b48ac43c6b4c4bf6202795832c38d3919"
#     }
#   ]
# }

# %% [markdown]
# ### 6.2 Download Asset

# %%
# Download Asset
try:
    file_content = client.download_asset(
        asset_path="document/pdf/water",
        version_id="1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",  # Must match the version_id obtained from list versions above
        return_file_content=True                                                    # True downloads file content, False only gets file info
    )
    # Save to local
    import os 
    os.makedirs("downloads", exist_ok=True)
    with open("downloads/downloaded_file.pdf", "wb") as f:
        f.write(file_content)
    print("✓ File download successful")
    # print("（示範程式碼 - 需要實際的 asset_path 和 version_id）")
except Exception as e:
    print(f"Download failed: {e}")
# Out:
# ✓ 檔案下載成功

# %% [markdown]
# ### 6.3 Archive Asset
#
# Archive function is currently not available, will return error message after execution.

# %%
# Archive Asset
try:
    result = client.archive_asset(
        asset_path="document/pdf/water",
        version_id="1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82"
    )
    print("Archive successful:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - 需要實際的 asset_path 和 version_id）")
except Exception as e:
    print(f"Archive failed: {e}")
# Out:
# 封存失敗: 500 Server Error: Internal Server Error for url: http://raptor_open_0_1_api.dhtsolution.com:8012/api/v1/asset/filearchive?asset_path=document%2Fpdf%2Fwater&version_id=1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82

# %% [markdown]
# ### 6.4 Delete Asset
#
# Delete function is currently not available, will return error message after execution.

# %%
# Delete archived asset
try:
    result = client.delete_asset(
        asset_path="document/pdf/water",
        version_id="1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82"
    )
    print("Delete successful:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - 需要實際的 asset_path 和 version_id）")
except Exception as e:
    print(f"Delete failed: {e}")
# Out:
# 刪除失敗: 500 Server Error: Internal Server Error for url: http://raptor_open_0_1_api.dhtsolution.com:8012/api/v1/asset/delfile?asset_path=document%2Fpdf%2Fwater&version_id=1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82

# %% [markdown]
# ## 7. Data Processing
#
# ### 7.1 Process Uploaded File
# **Note**: Need to have uploaded files before processing. Already processed files cannot be processed again.

# %%
# Process Uploaded File
try:
    result = client.process_file(
        upload_result={
            "asset_path": "document/pdf/water",
            "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
            "filename": "water.pdf"
        }
    )
    print("Processing result:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - Requires actual upload result）")
except Exception as e:
    print(f"Processing failed: {e}")
# Out:
# 處理失敗: 400 Client Error: Bad Request for url: http://raptor_open_0_1_api.dhtsolution.com:8012/api/v1/processing/process-file

# %% [markdown]
# ### 7.2 Query Cache Data

# %%
# Get specific cache
try:
    cached_value = client.get_cached_value(
        m_type="document",                     # Media type - one of: document, video, image, audio
        key="deb52768-7fa9-4375-922f-c36c09ab222d"
    )
    print("Cache value:")
    print(json.dumps(cached_value, indent=2, ensure_ascii=False))
    # print("（示範程式碼 - Requires actual cache key）")
except Exception as e:
    print(f"Query failed: {e}")

# Get all cache
try:
    all_cache = client.get_all_cache()
    print("All cache:")
    print(json.dumps(all_cache, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Query failed: {e}")
# Out:
# 快取值:
# {
#   "key": "document_orchestrator:deb52768-7fa9-4375-922f-c36c09ab222d",
#   "original_key": "deb52768-7fa9-4375-922f-c36c09ab222d",
#   "m_type": "document",
#   "value": "{\"step\": \"complete\", \"summary\": \"「water.pdf」文檔主要描述了一個為提升客戶服務效率與品質而建置的AI智能客服系統專案。該系統涵蓋了現有客服系統的說明與新系統的規劃，預算總計新臺幣10,479,000元。文檔詳細列出了開發和維護階段的工作內容、費用細項及各階段的目標和成果展示要求。此外，還強調了系統的安全性和維護要求，包括定期備份與回存演練、24小時內處理故障等。該專案通過多個階段逐步實現，旨在提供一個全面且高效的智能客服平臺。\"}"
# }
# 所有快取:
# {
#   "count": 1,
#   "data": {
#     "document_orchestrator:deb52768-7fa9-4375-922f-c36c09ab222d": "{\"step\": \"complete\", \"summary\": \"「water.pdf」文檔主要描述了一個為提升客戶服務效率與品質而建置的AI智能客服系統專案。該系統涵蓋了現有客服系統的說明與新系統的規劃，預算總計新臺幣10,479,000元。文檔詳細列出了開發和維護階段的工作內容、費用細項及各階段的目標和成果展示要求。此外，還強調了系統的安全性和維護要求，包括定期備份與回存演練、24小時內處理故障等。該專案通過多個階段逐步實現，旨在提供一個全面且高效的智能客服平臺。\"}"
#   }
# }

# %% [markdown]
# ## 8. Chat Features
#
# ### 8.1 Send Chat Message

# %%
# Send Chat Message
try:
    result = client.send_chat(
        user_id="test_user1",
        message="What are the expected contents of the water company tender?"
    )
    print("AI Response:")
    print(json.dumps(result, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Chat failed: {e}")
# Out:
# AI 回應:
# {
#   "response": "根據台灣自來水公司的標案預計內容，包含以下幾個主要部分：\n\n1. **基本資訊**：\n   - 施作地點：指定地區或設施。\n   - 施作內容：具體的工程或服務描述。\n\n2. **技術規範**：\n   - 工程規格：包括材料、設計標準等。\n   - 檢測標準：施工過程中的檢測要求和方法。\n   - 安全規範：施作過程中需遵守的安全措施。\n\n3. **行政與法律**：\n   - 合約條款：包括價格、支付方式、合約期限等。\n   - 法律依據：相關法規和標準。\n   - 環保要求：施作過程中需遵守的環保法規。\n\n4. **管理與執行**：\n   - 進度計劃：工程的時間表和里程碑。\n   - 質量控制：施工過程中的質量檢查和管理措施。\n   - 錯誤處理：發生錯誤時的處理流程。\n\n這些內容旨在確保標案的透明度、公正性，並且能夠有效地執行工程或服務。",
#   "user_id": "test_user1",
#   "search_triggered": true,
#   "search_results": [
#     {
#       "collection": "unified",
#       "items": [
#         {
#           "type": "document",
#           "collection": "document",
#           "score": 0.589437,
#           "id": "ef4db5e2-ba2f-4d3b-a4db-06b0cbc7527f",
#           "payload": {
#             "document_id": "water_chunk_0",
#             "type": "documents",
#             "text": "台灣自來水公司 - AI智能客服系統建置案\n\n<IMAGE>\n這張圖片是台灣自來水公司的標誌和名稱。\n</IMAGE>\n\nTAIWAN\n\nCORPORATION\n\nWATER\n\nAI智能客服系統建置案 服務建議書徵求須知（RFP）\n\n中華民國114年3月\n\n台灣自來水公司 - AI智能客服系統建置案\n\n目      錄\n\n<TABLE>\n| 壹、 | 專案概述 ................................................................................................................................................. 1 |\n| --- | --- |\n| 貳、 | 專案說明 ................................................................................................................................................. 1 |\n| 一、 | 專案名稱及性質 ................................................................................................................................. 1 |\n| 二、 | 專案目標 ............................................................................................................................................. 1 |\n| 三、 | 專案範圍 ............................................................................................................................................. 2 |\n| 四、 | 專案期程(詳第41頁專案期程圖)及交付文件 ............................................................................... 2 |\n| 五、 | 專案經費 ............................................................................................................................................. 7 |\n| 參、 | 系統架構說明 ......................................................................................................................................... 8 |\n| 一、 | 現有客服系統說明 ............................................................................................................................. 8 |\n| 二、 | 本案AI智能客服系統建置規劃 ....................................................................................................... 9 |\n| 肆、 | 專案需求說明 ....................................................................................................................................... 11 |\n| 一、 | 雲地環境分工 ................................................................................................................................... 11 |\n| 二、 | 分階開發工作 ................................................................................................................................... 14 |\n| 三、 | 系統入口及介接系統 ....................................................................................................................... 16 |\n| 四、 | 生成式 AI 智慧客服核心 ............................................................................................................... 18 |\n| 五、 | 服務水準-問答正確率 ..................................................................................................................... 19 |\n| 六、 智能客服調校 | ................................................................................................................................... 21 |\n| 七、 | 網頁及使用者介面優化 ................................................................................................................... 22 |\n| 八、 | 前台服務功能 ................................................................................................................................... 23 |\n| 九、 | 智能客服知識點(庫)問答建立及整合功能 ................................................................................... 25 |\n| 十、 | 後台管理功能 ................................................................................................................................... 26 |\n| 十一、 | 系統正常運作需求 ....................................................................................................................... 29 |\n| 十二、 | 教育訓練 ....................................................................................................................................... 30 |\n| 十三、 | 個資保障機制 ............................................................................................................................... 31 |\n| 十四、 | 資訊安全 ....................................................................................................................................... 32 |\n| 十五、 | 保密義務 ........................................................... ...
#             "filename": "water.pdf",
#             "source": "pdf",
#             "chunk_index": 0,
#             "page_numbers": [
#               1,
#               2,
#               3
#             ],
#             "element_types": [
#               "image",
#               "text",
#               "table"
#             ],
#             "char_count": 5253,
#             "upload_time": "2025-11-14T12:37:13.426327",
#             "embedding_type": "text",
#             "asset_path": "document/pdf/water",
#             "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#             "status": "active"
#           }
#         },
#         {
#           "type": "document",
#           "collection": "document",
#           "score": 0.5875207,
#           "id": "e85c5608-c9fd-40a8-bc00-13e214481a3c",
#           "payload": {
#             "document_id": "water_chunk_21",
#             "type": "documents",
#             "text": "(1)水質即時資訊\n\n(3)通訊地址變更\n\n2.收費類\n\n(4)取消委託代繳\n\n(1)網路 E 櫃台\n\n(5)自報水表指針(抄表日水表指數\n\na.線上查詢\n\n未抄到補報)\n\n(a)水費試算查詢\n\n(5)突增水費複查\n\n(b)新/改裝進度查詢\n\n(6)繳費證明\n\n(c)線上申辦進度查詢\n\n(7)裝置證明\n\nb.線上繳費:\n\n(8)補開水單(紙本水費通知單)\n\n(a)信用卡\n\n(9)用水地址更正\n\n(b)網路繳費\n\n(10)變更統一編號(公司行號新增、 修改、刪除)。\n\n(c)繳費方式簡介\n\n(d)產製繳費 QR Code\n\n(11)電話號碼變更\n\n3.線上申辦：\n\n(12)水表 e 管家開通服務\n\n(1)新裝工程預約初/預審內線圖申 請、臨時恢復普通用水、復用、啟 用、停用、廢止(以上屬預約性質)\n\n(13)電子/簡訊帳單：取消、變更電 子信箱\n\n4.下載專區\n\n(1)申請表格\n\n第2階段RAG：透過網路爬蟲或介接API取得台灣自來水全球網及所屬單位網站 之資料、文件、訊息，如有新增法規及作業規定可依需求訪談新增\n\n1.政府資訊公開-法規命令\n\n2.公告資訊\n\n(1)營業章程\n\n(1)訊息公佈欄\n\n(2)自來水用戶用水設備標準\n\n(2)區域 hot 新聞\n\n(3)水利法\n\n(3)闢謠專區\n\n(4)水利法施行細則\n\n(4)公司重大政策\n\n(5)自來水法\n\n3.用水宣導：\n\n(6)自來水法施行細則\n\n(1)用水須知(網頁文字部分)",
#             "filename": "water.pdf",
#             "source": "pdf",
#             "chunk_index": 21,
#             "page_numbers": [
#               18
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 622,
#             "upload_time": "2025-11-14T12:37:13.426327",
#             "embedding_type": "text",
#             "asset_path": "document/pdf/water",
#             "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#             "status": "active"
#           }
#         },
#         {
#           "type": "image",
#           "collection": "image",
#           "score": 0.41174898,
#           "id": "46f88c30-5983-4025-a5fe-80c6bcc01a9d",
#           "payload": {
#             "document_id": "test.jpg_chunk_0",
#             "type": "images",
#             "text": "跨多產業 多文件中心 劉更管制 文件安控\n\n完善「品質文件管制」機制、業界最廣用途文管中心\n最佳品質文件管制平臺\n\nWebISO PRO 完善「品質文件」最重要的：文件變更管制、發行閱讀任務，更導入最新「多文件中 心」架構 讓服務業、營建業、醫療業、政府機關...等，適合多種產業，是市面上功能最廣泛用途的品質文件管制中心\n\n製造業 服務業\nISO標準書SOP文件 製程技術文件 RoHS認證文件 合約管理 生產線週期表 PLM/PDM流程整合 EMS/MES品保整合 單店證照/執照 合約管理 SGS食品檢驗文件 中央工廠SOP文件 維修進度報告 文件 工程設計圖面 進 度報告文件 維修進度報告 文件 合約、保險管理 矮工、施工記錄 ERPP/HR流程整合 單P/HR流程整合 規章制度文件\n\n營建業 醫療業\nISO制度SOP文 件 壺地專案文 件 政府收發文紀錄 單衛生主管機關文書 診療技術文件 單 論療設備操作文件 單 醫院評鑑紀錄 醫院SOP制度文 件 單 內部審查與紀錄\n\nNO_TEXT_FOUND",
#             "filename": "test.jpg",
#             "source": "jpg",
#             "chunk_index": 0,
#             "page_numbers": [
#               1
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 457,
#             "upload_time": "2025-10-28T05:02:43.428031+00:00",
#             "embedding_type": "text",
#             "asset_path": "image/jpg/test",
#             "version_id": "89eee3f685ae066475fd0db3ae9f38bce6d1e16f5d4f81f1a2e4fae9ae66f55d",
#             "status": "active"
#           }
#         },
#         {
#           "type": "image",
#           "collection": "image",
#           "score": 0.4090097,
#           "id": "188dabe1-6732-4356-8551-d9eb4a162388",
#           "payload": {
#             "document_id": "模型圖.jpg_chunk_0",
#             "type": "images",
#             "text": "怎麼可能? RoBERTa HT Text Projection H'' Query Cross-Attention\n\nH'' H'-A\nWav2Vec2 HA Audio Projection \nCross-Attention \n特徵提取與投影 跨模態注意力\n\nPool\nGate\nFusion Hfused \n門控融合 分類器 \n\n正  中立 負面\n Classifier",
#             "filename": "模型圖.jpg",
#             "source": "jpg",
#             "chunk_index": 0,
#             "page_numbers": [
#               1
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 188,
#             "upload_time": "2025-10-31T04:46:59.262904+00:00",
#             "embedding_type": "text",
#             "asset_path": "image/jpg/模型圖",
#             "version_id": "36515e0745776a735c38ebca554576396b5198aaf5fbeef58fa527f6f8945b26",
#             "status": "active"
#           }
#         },
#         {
#           "type": "video",
#           "collection": "video",
#           "score": 0.40737635,
#           "id": "fe8925d6-7e02-4cbd-8730-ad87ee105185",
#           "payload": {
#             "audio_id": "YTtest1.mp4_chunk_18",
#             "text": "這裏他提示規範已經創建成功這裏是這個文件存放的路徑這裏是總結在這裏就是具體的功能下面是三個需要澄清的地方包括使用期間的通話行爲是暫停還是放棄還有設備日期時間的操作處理還有繪畫在午夜完成應該統計哪天的數據",
#             "filename": "YTtest1.mp4",
#             "chunk_index": 18,
#             "start_time": "407.798",
#             "end_time": "427.88",
#             "speaker": "SPEAKER_00",
#             "type": "videos",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T18:26:45.827703",
#             "embedding_type": "text",
#             "asset_path": "video/mp4/YTtest1",
#             "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#             "status": "active"
#           }
#         },
#         {
#           "type": "video",
#           "collection": "video",
#           "score": 0.40323895,
#           "id": "17913ba6-67ef-4715-8af0-68bce7ef32b3",
#           "payload": {
#             "audio_id": "YTtest1.mp4_chunk_0",
#             "text": "最近很多粉絲私信讓我講講GitHub上開源的SpecKey項目經過我這段時間的測試和使用發現這個項目比我們之前介紹的SpecWorkflow MCP效果要更好我們只需要用到幾個命令就可以把需求寫成可執行的規範再讓AI自動產出計劃任務最後按任務寫代碼並完成項目開發而且這個項目上手很快幾分鐘就能跑通",
#             "filename": "YTtest1.mp4",
#             "chunk_index": 0,
#             "start_time": "5.903",
#             "end_time": "29.275",
#             "speaker": "SPEAKER_00",
#             "type": "videos",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T18:26:45.827703",
#             "embedding_type": "text",
#             "asset_path": "video/mp4/YTtest1",
#             "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#             "status": "active"
#           }
#         },
#         {
#           "type": "audio",
#           "collection": "audio",
#           "score": 0.35008025,
#           "id": "41b8a29a-dc5a-4102-977b-98f9656cfb45",
#           "payload": {
#             "audio_id": "AI02_chunk_3",
#             "text": "第三個問題後,計劃是這樣計劃的,它會指示模型關閉。",
#             "filename": "AI02.wav",
#             "chunk_index": 3,
#             "start_time": "59.313",
#             "end_time": "66.333",
#             "speaker": "SPEAKER_02",
#             "type": "audios",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T09:01:16.246059+00:00",
#             "embedding_type": "text",
#             "asset_path": "audio/x-wav/AI02",
#             "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#             "status": "active"
#           }
#         },
#         {
#           "type": "audio",
#           "collection": "audio",
#           "score": 0.3433343,
#           "id": "45bb0d9c-c2c7-4526-b959-1f479b996364",
#           "payload": {
#             "audio_id": "AI02_chunk_5",
#             "text": "It learns that it is getting replacedThe AI model is getting replacedIt finds outSo what does the model doIt starts combing through emailsIt learns that the engineer responsible for it is having an affairSo Opus makes a choiceIt chooses survival over ethics",
#             "filename": "AI02.wav",
#             "chunk_index": 5,
#             "start_time": "95.965",
#             "end_time": "113.802",
#             "speaker": "SPEAKER_02",
#             "type": "audios",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T09:01:16.246203+00:00",
#             "embedding_type": "text",
#             "asset_path": "audio/x-wav/AI02",
#             "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#             "status": "active"
#           }
#         }
#       ],
#       "stats": {
#         "video": {
#           "count": 2,
#           "avg_score": 0.40530765
#         },
#         "audio": {
#           "count": 2,
#           "avg_score": 0.346707275
#         },
#         "document": {
#           "count": 2,
#           "avg_score": 0.58847885
#         },
#         "image": {
#           "count": 2,
#           "avg_score": 0.41037934
#         }
#       },
#       "query": ">自來水標案預計內容有哪些？"
#     }
#   ],
#   "tool_calls": [
#     {
#       "tool": "unified_search_tool",
#       "query": ">自來水標案預計內容有哪些？",
#       "results_count": 8,
#       "execution_time_ms": 2820.3155994415283,
#       "error": null,
#       "api_endpoint": null
#     }
#   ]
# }

# %% [markdown]
# ### 8.2 Chat with Search Results

# %%
# First search, then pass results to chat
try:
    # 1. 搜尋相關內容
    search_results = client.document_search(
        query_text="water company",               # Search keyword
        embedding_type="text",            # Use text embedding text or summary
        filename=["water.pdf"],           # Specify filename  (Optional)
        source="pdf",                     # Specify data source as PDF  (Optional)
        limit=1                           # Limit search result count  (Optional, Default 5)
    )
    print("✓ Search completed")
    print(json.dumps(search_results, indent=2, ensure_ascii=False))
    
    # 2. 將搜尋結果傳給聊天
    chat_response = client.send_chat(
        user_id="test_user1",
        message="請根據這些搜尋結果Summary重點",
        search_results=search_results.get("items", [])
    )
    print("\nAI Response:")
    print(json.dumps(chat_response, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Failed: {e}")
# Out:
# ✓ 搜尋完成
# {
#   "success": true,
#   "total": 1,
#   "results": [
#     {
#       "score": 0.59000933,
#       "id": "e85c5608-c9fd-40a8-bc00-13e214481a3c",
#       "payload": {
#         "document_id": "water_chunk_21",
#         "type": "documents",
#         "text": "(1)水質即時資訊\n\n(3)通訊地址變更\n\n2.收費類\n\n(4)取消委託代繳\n\n(1)網路 E 櫃台\n\n(5)自報水表指針(抄表日水表指數\n\na.線上查詢\n\n未抄到補報)\n\n(a)水費試算查詢\n\n(5)突增水費複查\n\n(b)新/改裝進度查詢\n\n(6)繳費證明\n\n(c)線上申辦進度查詢\n\n(7)裝置證明\n\nb.線上繳費:\n\n(8)補開水單(紙本水費通知單)\n\n(a)信用卡\n\n(9)用水地址更正\n\n(b)網路繳費\n\n(10)變更統一編號(公司行號新增、 修改、刪除)。\n\n(c)繳費方式簡介\n\n(d)產製繳費 QR Code\n\n(11)電話號碼變更\n\n3.線上申辦：\n\n(12)水表 e 管家開通服務\n\n(1)新裝工程預約初/預審內線圖申 請、臨時恢復普通用水、復用、啟 用、停用、廢止(以上屬預約性質)\n\n(13)電子/簡訊帳單：取消、變更電 子信箱\n\n4.下載專區\n\n(1)申請表格\n\n第2階段RAG：透過網路爬蟲或介接API取得台灣自來水全球網及所屬單位網站 之資料、文件、訊息，如有新增法規及作業規定可依需求訪談新增\n\n1.政府資訊公開-法規命令\n\n2.公告資訊\n\n(1)營業章程\n\n(1)訊息公佈欄\n\n(2)自來水用戶用水設備標準\n\n(2)區域 hot 新聞\n\n(3)水利法\n\n(3)闢謠專區\n\n(4)水利法施行細則\n\n(4)公司重大政策\n\n(5)自來水法\n\n3.用水宣導：\n\n(6)自來水法施行細則\n\n(1)用水須知(網頁文字部分)",
#         "filename": "water.pdf",
#         "source": "pdf",
#         "chunk_index": 21,
#         "page_numbers": [
#           18
#         ],
#         "element_types": [
#           "text"
#         ],
#         "char_count": 622,
#         "upload_time": "2025-11-14T12:37:13.426327",
#         "embedding_type": "text",
#         "asset_path": "document/pdf/water",
#         "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#         "status": "active"
#       }
#     }
#   ]
# }
#
# AI 回應:
# {
#   "response": "根據搜尋結果，最相關的文件是一個PDF文件（9708.pdf），內容涉及到對某些句子進行錯誤修訂和填空測試。以下是該文件的一些重點：\n\n1. **錯誤修訂**：\n   - 這部分的內容包括對一些不正確的詞語或短語進行修改，例如：\n     ```\n     This chapter compares and contrasts the politic use and impact of quotas on (A) practices in the latter half of the twentieth century hiring.\n     Oftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs.\n     if a couple months left init; 4 got\n     There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n     If he can stay out bx her friends until midnight, why can't (A).\n     I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n     ```\n   - 這些句子中有多個錯誤需要修正。\n\n2. **填空測試**：\n   - 文件中的CLOZE TEST部分要求讀者選擇適當的單詞來填充空白，例如：\n     ```\n     Researchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders, since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very.\n     Still , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26).\n     ```\n   - 這些空白需要填充適當的詞語。\n\n3. **討論**：\n   - 文件還包括對某些研究結果的討論，例如：\n     ```\n     Dr. Peterson noted, \"This is all very strong evidence; and avery good set of leads, but we can't (27) say that we have proved the involvement of these regions in autism.\"\n     ```\n\n根據上述內容，這個PDF文件主要涉及到語言錯誤的修訂和填空測試，並包括一些與自閉症相關研究的討論。",
#   "user_id": "test_user1",
#   "search_triggered": true,
#   "search_results": [
#     {
#       "collection": "unified",
#       "items": [
#         {
#           "type": "document",
#           "collection": "document",
#           "score": 0.49348626,
#           "id": "e9f74d52-7829-408a-8774-76316354e5a2",
#           "payload": {
#             "document_id": "96008_chunk_2",
#             "type": "documents",
#             "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#             "filename": "96008.pdf",
#             "source": "pdf",
#             "chunk_index": 2,
#             "page_numbers": [
#               2,
#               3
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 1512,
#             "upload_time": "2025-11-06T18:25:40.229136",
#             "embedding_type": "text",
#             "asset_path": "document/pdf/96008",
#             "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#             "status": "active"
#           }
#         },
#         {
#           "type": "document",
#           "collection": "document",
#           "score": 0.49348626,
#           "id": "959393be-158e-482c-a0ac-c46528d9d3bc",
#           "payload": {
#             "document_id": "96008_chunk_2",
#             "type": "documents",
#             "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#             "filename": "96008.pdf",
#             "source": "pdf",
#             "chunk_index": 2,
#             "page_numbers": [
#               2,
#               3
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 1512,
#             "upload_time": "2025-11-06T18:25:23.298399",
#             "embedding_type": "text",
#             "asset_path": "document/pdf/96008",
#             "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#             "status": "active"
#           }
#         },
#         {
#           "type": "image",
#           "collection": "image",
#           "score": 0.4833184,
#           "id": "c9a5dd64-797b-45f3-b410-aa646cea45b8",
#           "payload": {
#             "document_id": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg_chunk_0",
#             "type": "images",
#             "text": "VALLENTINE 45\nWILLIAMS 44\nPRITCHARD 11\n ups\nNCAAM\nNCAAM\n\nNO其他文字需要提取",
#             "filename": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg",
#             "source": "jpg",
#             "chunk_index": 0,
#             "page_numbers": [
#               1
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 67,
#             "upload_time": "2025-10-31T03:15:50.698020+00:00",
#             "embedding_type": "text",
#             "asset_path": "image/jpg/Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_",
#             "version_id": "378787f28e90ac6dae5e7dedbcfaee4965d5e053f6a247acdb208f4f0c35f63b",
#             "status": "active"
#           }
#         },
#         {
#           "type": "image",
#           "collection": "image",
#           "score": 0.48303294,
#           "id": "b798dbfe-8782-4a90-948a-272dac5709dd",
#           "payload": {
#             "document_id": "test.jpg_chunk_0",
#             "type": "images",
#             "text": "NO_TEXT_FOUND",
#             "filename": "test.jpg",
#             "source": "jpg",
#             "chunk_index": 0,
#             "page_numbers": [
#               1
#             ],
#             "element_types": [
#               "text"
#             ],
#             "char_count": 13,
#             "upload_time": "2025-10-28T09:02:27.336838+00:00",
#             "embedding_type": "text",
#             "asset_path": "image/jpg/test",
#             "version_id": "9690223a3678339b984027ba7f7c511b207d700bb0a284fa091c392e6abd38be",
#             "status": "active"
#           }
#         },
#         {
#           "type": "video",
#           "collection": "video",
#           "score": 0.47484303,
#           "id": "fe8925d6-7e02-4cbd-8730-ad87ee105185",
#           "payload": {
#             "audio_id": "YTtest1.mp4_chunk_18",
#             "text": "這裏他提示規範已經創建成功這裏是這個文件存放的路徑這裏是總結在這裏就是具體的功能下面是三個需要澄清的地方包括使用期間的通話行爲是暫停還是放棄還有設備日期時間的操作處理還有繪畫在午夜完成應該統計哪天的數據",
#             "filename": "YTtest1.mp4",
#             "chunk_index": 18,
#             "start_time": "407.798",
#             "end_time": "427.88",
#             "speaker": "SPEAKER_00",
#             "type": "videos",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T18:26:45.827703",
#             "embedding_type": "text",
#             "asset_path": "video/mp4/YTtest1",
#             "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#             "status": "active"
#           }
#         },
#         {
#           "type": "video",
#           "collection": "video",
#           "score": 0.43846,
#           "id": "ff718285-56b8-491b-9348-1a308ef69ab0",
#           "payload": {
#             "audio_id": "YTtest1.mp4_chunk_14",
#             "text": "因爲我要開發一款原生的iOS番茄專注app所以我這裏就輸入對應的提示詞我輸入的提示詞是保持iOS forest風格的專注應用要求極致簡潔並支持離線優先強制執行測試驅動開發60fps動畫小於兩秒的冷啓動並且支持voice over dynamic type我們直接運行先看一下這個效果這裏開始運行這樣他就會創建這個項目的原則和開發規範",
#             "filename": "YTtest1.mp4",
#             "chunk_index": 14,
#             "start_time": "308.337",
#             "end_time": "337.649",
#             "speaker": "SPEAKER_00",
#             "type": "videos",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T18:26:45.827703",
#             "embedding_type": "text",
#             "asset_path": "video/mp4/YTtest1",
#             "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#             "status": "active"
#           }
#         },
#         {
#           "type": "audio",
#           "collection": "audio",
#           "score": 0.43139476,
#           "id": "efba631e-6231-4857-9b02-c20d3d472215",
#           "payload": {
#             "audio_id": "AI02_chunk_1",
#             "text": "03就在這裏,有近140IQ,太厲害了01 Pro有120IQ,01 baseline有90IQ",
#             "filename": "AI02.wav",
#             "chunk_index": 1,
#             "start_time": "22.593",
#             "end_time": "35.08",
#             "speaker": "SPEAKER_00",
#             "type": "audios",
#             "audio_labels": [
#               "Speech"
#             ],
#             "upload_time": "2025-10-27T09:01:16.245913+00:00",
#             "embedding_type": "text",
#             "asset_path": "audio/x-wav/AI02",
#             "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#             "status": "active"
#           }
#         },
#         {
#           "type": "audio",
#           "collection": "audio",
#           "score": 0.41946447,
#           "id": "af882964-90ef-4882-8b44-4a6cd4f59555",
#           "payload": {
#             "audio_id": "YTtest2_chunk_0",
#             "text": "哈囉大家好我是顏仁烈今天要講的動漫是進擊的巨人",
#             "filename": "YTtest2.wav",
#             "chunk_index": 0,
#             "start_time": "11.692",
#             "end_time": "15.657",
#             "speaker": "SPEAKER_00",
#             "type": "audios",
#             "audio_labels": [],
#             "upload_time": "2025-10-27T10:14:15.245030+00:00",
#             "embedding_type": "text",
#             "asset_path": "audio/x-wav/YTtest2",
#             "version_id": "9314c1539edc0e84016d9f63fcd957131c5d61bc205fa06e252848e90d320962",
#             "status": "active"
#           }
#         }
#       ],
#       "stats": {
#         "video": {
#           "count": 2,
#           "avg_score": 0.456651515
#         },
#         "audio": {
#           "count": 2,
#           "avg_score": 0.425429615
#         },
#         "document": {
#           "count": 2,
#           "avg_score": 0.49348626
#         },
#         "image": {
#           "count": 2,
#           "avg_score": 0.48317567
#         }
#       },
#       "query": "請根據這些搜尋結果總結重點"
#     }
#   ],
#   "tool_calls": [
#     {
#       "tool": "unified_search_tool",
#       "query": "請根據這些搜尋結果總結重點",
#       "results_count": 8,
#       "execution_time_ms": 2701.5764713287354,
#       "error": null,
#       "api_endpoint": null
#     }
#   ]
# }

# %% [markdown]
# ### 8.3 Manage Chat Memory

# %%
# Get chat memory
try:
    memory = client.get_chat_memory(user_id="test_user1")
    print("Chat memory:")
    print(json.dumps(memory, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"取得記憶Failed: {e}")
# Out:
# 聊天記憶:
# {
#   "user_id": "test_user1",
#   "memory_count": 3,
#   "memories": [
#     {
#       "timestamp": 1763096580.6287272,
#       "user_message": "自來水標案預計內容有哪些？",
#       "assistant_response": "根據台灣自來水公司的標案預計內容，包含以下幾個主要部分：\n\n1. **基本資訊**：\n   - 施作地點：指定地區或設施。\n   - 施作內容：具體的工程或服務描述。\n\n2. **技術規範**：\n   - 工程規格：包括材料、設計標準等。\n   - 檢測標準：施工過程中的檢測要求和方法。\n   - 安全規範：施作過程中需遵守的安全措施。\n\n3. **行政與法律**：\n   - 合約條款：包括價格、支付方式、合約期限等。\n   - 法律依據：相關法規和標準。\n   - 環保要求：施作過程中需遵守的環保法規。\n\n4. **管理與執行**：\n   - 進度計劃：工程的時間表和里程碑。\n   - 質量控制：施工過程中的質量檢查和管理措施。\n   - 錯誤處理：發生錯誤時的處理流程。\n\n這些內容旨在確保標案的透明度、公正性，並且能夠有效地執行工程或服務。",
#       "search_results": [
#         {
#           "collection": "unified",
#           "items": [
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.589437,
#               "id": "ef4db5e2-ba2f-4d3b-a4db-06b0cbc7527f",
#               "payload": {
#                 "document_id": "water_chunk_0",
#                 "type": "documents",
#                 "text": "台灣自來水公司 - AI智能客服系統建置案\n\n<IMAGE>\n這張圖片是台灣自來水公司的標誌和名稱。\n</IMAGE>\n\nTAIWAN\n\nCORPORATION\n\nWATER\n\nAI智能客服系統建置案 服務建議書徵求須知（RFP）\n\n中華民國114年3月\n\n台灣自來水公司 - AI智能客服系統建置案\n\n目      錄\n\n<TABLE>\n| 壹、 | 專案概述 ................................................................................................................................................. 1 |\n| --- | --- |\n| 貳、 | 專案說明 ................................................................................................................................................. 1 |\n| 一、 | 專案名稱及性質 ................................................................................................................................. 1 |\n| 二、 | 專案目標 ............................................................................................................................................. 1 |\n| 三、 | 專案範圍 ............................................................................................................................................. 2 |\n| 四、 | 專案期程(詳第41頁專案期程圖)及交付文件 ............................................................................... 2 |\n| 五、 | 專案經費 ............................................................................................................................................. 7 |\n| 參、 | 系統架構說明 ......................................................................................................................................... 8 |\n| 一、 | 現有客服系統說明 ............................................................................................................................. 8 |\n| 二、 | 本案AI智能客服系統建置規劃 ....................................................................................................... 9 |\n| 肆、 | 專案需求說明 ....................................................................................................................................... 11 |\n| 一、 | 雲地環境分工 ................................................................................................................................... 11 |\n| 二、 | 分階開發工作 ................................................................................................................................... 14 |\n| 三、 | 系統入口及介接系統 ....................................................................................................................... 16 |\n| 四、 | 生成式 AI 智慧客服核心 ............................................................................................................... 18 |\n| 五、 | 服務水準-問答正確率 ..................................................................................................................... 19 |\n| 六、 智能客服調校 | ................................................................................................................................... 21 |\n| 七、 | 網頁及使用者介面優化 ................................................................................................................... 22 |\n| 八、 | 前台服務功能 ................................................................................................................................... 23 |\n| 九、 | 智能客服知識點(庫)問答建立及整合功能 ................................................................................... 25 |\n| 十、 | 後台管理功能 ................................................................................................................................... 26 |\n| 十一、 | 系統正常運作需求 ....................................................................................................................... 29 |\n| 十二、 | 教育訓練 ....................................................................................................................................... 30 |\n| 十三、 | 個資保障機制 ............................................................................................................................... 31 |\n| 十四、 | 資訊安全 ....................................................................................................................................... 32 |\n| 十五、 | 保密義務 ....................................................... ...
#                 "filename": "water.pdf",
#                 "source": "pdf",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1,
#                   2,
#                   3
#                 ],
#                 "element_types": [
#                   "image",
#                   "text",
#                   "table"
#                 ],
#                 "char_count": 5253,
#                 "upload_time": "2025-11-14T12:37:13.426327",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/water",
#                 "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.5875207,
#               "id": "e85c5608-c9fd-40a8-bc00-13e214481a3c",
#               "payload": {
#                 "document_id": "water_chunk_21",
#                 "type": "documents",
#                 "text": "(1)水質即時資訊\n\n(3)通訊地址變更\n\n2.收費類\n\n(4)取消委託代繳\n\n(1)網路 E 櫃台\n\n(5)自報水表指針(抄表日水表指數\n\na.線上查詢\n\n未抄到補報)\n\n(a)水費試算查詢\n\n(5)突增水費複查\n\n(b)新/改裝進度查詢\n\n(6)繳費證明\n\n(c)線上申辦進度查詢\n\n(7)裝置證明\n\nb.線上繳費:\n\n(8)補開水單(紙本水費通知單)\n\n(a)信用卡\n\n(9)用水地址更正\n\n(b)網路繳費\n\n(10)變更統一編號(公司行號新增、 修改、刪除)。\n\n(c)繳費方式簡介\n\n(d)產製繳費 QR Code\n\n(11)電話號碼變更\n\n3.線上申辦：\n\n(12)水表 e 管家開通服務\n\n(1)新裝工程預約初/預審內線圖申 請、臨時恢復普通用水、復用、啟 用、停用、廢止(以上屬預約性質)\n\n(13)電子/簡訊帳單：取消、變更電 子信箱\n\n4.下載專區\n\n(1)申請表格\n\n第2階段RAG：透過網路爬蟲或介接API取得台灣自來水全球網及所屬單位網站 之資料、文件、訊息，如有新增法規及作業規定可依需求訪談新增\n\n1.政府資訊公開-法規命令\n\n2.公告資訊\n\n(1)營業章程\n\n(1)訊息公佈欄\n\n(2)自來水用戶用水設備標準\n\n(2)區域 hot 新聞\n\n(3)水利法\n\n(3)闢謠專區\n\n(4)水利法施行細則\n\n(4)公司重大政策\n\n(5)自來水法\n\n3.用水宣導：\n\n(6)自來水法施行細則\n\n(1)用水須知(網頁文字部分)",
#                 "filename": "water.pdf",
#                 "source": "pdf",
#                 "chunk_index": 21,
#                 "page_numbers": [
#                   18
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 622,
#                 "upload_time": "2025-11-14T12:37:13.426327",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/water",
#                 "version_id": "1d0af939d8fe5e603f9f3cea0049e10401e0d616083f557222f788695d730d82",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.41174898,
#               "id": "46f88c30-5983-4025-a5fe-80c6bcc01a9d",
#               "payload": {
#                 "document_id": "test.jpg_chunk_0",
#                 "type": "images",
#                 "text": "跨多產業 多文件中心 劉更管制 文件安控\n\n完善「品質文件管制」機制、業界最廣用途文管中心\n最佳品質文件管制平臺\n\nWebISO PRO 完善「品質文件」最重要的：文件變更管制、發行閱讀任務，更導入最新「多文件中 心」架構 讓服務業、營建業、醫療業、政府機關...等，適合多種產業，是市面上功能最廣泛用途的品質文件管制中心\n\n製造業 服務業\nISO標準書SOP文件 製程技術文件 RoHS認證文件 合約管理 生產線週期表 PLM/PDM流程整合 EMS/MES品保整合 單店證照/執照 合約管理 SGS食品檢驗文件 中央工廠SOP文件 維修進度報告 文件 工程設計圖面 進 度報告文件 維修進度報告 文件 合約、保險管理 矮工、施工記錄 ERPP/HR流程整合 單P/HR流程整合 規章制度文件\n\n營建業 醫療業\nISO制度SOP文 件 壺地專案文 件 政府收發文紀錄 單衛生主管機關文書 診療技術文件 單 論療設備操作文件 單 醫院評鑑紀錄 醫院SOP制度文 件 單 內部審查與紀錄\n\nNO_TEXT_FOUND",
#                 "filename": "test.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 457,
#                 "upload_time": "2025-10-28T05:02:43.428031+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/test",
#                 "version_id": "89eee3f685ae066475fd0db3ae9f38bce6d1e16f5d4f81f1a2e4fae9ae66f55d",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.4090097,
#               "id": "188dabe1-6732-4356-8551-d9eb4a162388",
#               "payload": {
#                 "document_id": "模型圖.jpg_chunk_0",
#                 "type": "images",
#                 "text": "怎麼可能? RoBERTa HT Text Projection H'' Query Cross-Attention\n\nH'' H'-A\nWav2Vec2 HA Audio Projection \nCross-Attention \n特徵提取與投影 跨模態注意力\n\nPool\nGate\nFusion Hfused \n門控融合 分類器 \n\n正  中立 負面\n Classifier",
#                 "filename": "模型圖.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 188,
#                 "upload_time": "2025-10-31T04:46:59.262904+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/模型圖",
#                 "version_id": "36515e0745776a735c38ebca554576396b5198aaf5fbeef58fa527f6f8945b26",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.40737635,
#               "id": "fe8925d6-7e02-4cbd-8730-ad87ee105185",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_18",
#                 "text": "這裏他提示規範已經創建成功這裏是這個文件存放的路徑這裏是總結在這裏就是具體的功能下面是三個需要澄清的地方包括使用期間的通話行爲是暫停還是放棄還有設備日期時間的操作處理還有繪畫在午夜完成應該統計哪天的數據",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 18,
#                 "start_time": "407.798",
#                 "end_time": "427.88",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.40323895,
#               "id": "17913ba6-67ef-4715-8af0-68bce7ef32b3",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_0",
#                 "text": "最近很多粉絲私信讓我講講GitHub上開源的SpecKey項目經過我這段時間的測試和使用發現這個項目比我們之前介紹的SpecWorkflow MCP效果要更好我們只需要用到幾個命令就可以把需求寫成可執行的規範再讓AI自動產出計劃任務最後按任務寫代碼並完成項目開發而且這個項目上手很快幾分鐘就能跑通",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 0,
#                 "start_time": "5.903",
#                 "end_time": "29.275",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.35008025,
#               "id": "41b8a29a-dc5a-4102-977b-98f9656cfb45",
#               "payload": {
#                 "audio_id": "AI02_chunk_3",
#                 "text": "第三個問題後,計劃是這樣計劃的,它會指示模型關閉。",
#                 "filename": "AI02.wav",
#                 "chunk_index": 3,
#                 "start_time": "59.313",
#                 "end_time": "66.333",
#                 "speaker": "SPEAKER_02",
#                 "type": "audios",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T09:01:16.246059+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/AI02",
#                 "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.3433343,
#               "id": "45bb0d9c-c2c7-4526-b959-1f479b996364",
#               "payload": {
#                 "audio_id": "AI02_chunk_5",
#                 "text": "It learns that it is getting replacedThe AI model is getting replacedIt finds outSo what does the model doIt starts combing through emailsIt learns that the engineer responsible for it is having an affairSo Opus makes a choiceIt chooses survival over ethics",
#                 "filename": "AI02.wav",
#                 "chunk_index": 5,
#                 "start_time": "95.965",
#                 "end_time": "113.802",
#                 "speaker": "SPEAKER_02",
#                 "type": "audios",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T09:01:16.246203+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/AI02",
#                 "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#                 "status": "active"
#               }
#             }
#           ],
#           "stats": {
#             "video": {
#               "count": 2,
#               "avg_score": 0.40530765
#             },
#             "audio": {
#               "count": 2,
#               "avg_score": 0.346707275
#             },
#             "document": {
#               "count": 2,
#               "avg_score": 0.58847885
#             },
#             "image": {
#               "count": 2,
#               "avg_score": 0.41037934
#             }
#           },
#           "query": ">自來水標案預計內容有哪些？",
#           "original_user_query": "自來水標案預計內容有哪些？"
#         }
#       ]
#     },
#     {
#       "timestamp": 1763096713.1055844,
#       "user_message": "請根據這些搜尋結果總結重點",
#       "assistant_response": "根據搜尋結果的分析，找不到與「請根據這些搜尋結果總結重點」相關性較高的資訊。其中最相關的文件是PDF文件，且其內容主要涉及語法和詞彙錯誤的更正，以及自閉症研究的一些細節。這些內容與總結搜尋結果沒有直接的關聯性，因此無法提供具體的重點總結。\n\n建議您可以提供更多相關的文件或資訊，以便進行更精確的分析和總結。",
#       "search_results": [
#         {
#           "collection": "unified",
#           "items": [
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.49348626,
#               "id": "e9f74d52-7829-408a-8774-76316354e5a2",
#               "payload": {
#                 "document_id": "96008_chunk_2",
#                 "type": "documents",
#                 "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#                 "filename": "96008.pdf",
#                 "source": "pdf",
#                 "chunk_index": 2,
#                 "page_numbers": [
#                   2,
#                   3
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 1512,
#                 "upload_time": "2025-11-06T18:25:40.229136",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/96008",
#                 "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.49348626,
#               "id": "959393be-158e-482c-a0ac-c46528d9d3bc",
#               "payload": {
#                 "document_id": "96008_chunk_2",
#                 "type": "documents",
#                 "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#                 "filename": "96008.pdf",
#                 "source": "pdf",
#                 "chunk_index": 2,
#                 "page_numbers": [
#                   2,
#                   3
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 1512,
#                 "upload_time": "2025-11-06T18:25:23.298399",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/96008",
#                 "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.4833184,
#               "id": "c9a5dd64-797b-45f3-b410-aa646cea45b8",
#               "payload": {
#                 "document_id": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg_chunk_0",
#                 "type": "images",
#                 "text": "VALLENTINE 45\nWILLIAMS 44\nPRITCHARD 11\n ups\nNCAAM\nNCAAM\n\nNO其他文字需要提取",
#                 "filename": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 67,
#                 "upload_time": "2025-10-31T03:15:50.698020+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_",
#                 "version_id": "378787f28e90ac6dae5e7dedbcfaee4965d5e053f6a247acdb208f4f0c35f63b",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.48303294,
#               "id": "b798dbfe-8782-4a90-948a-272dac5709dd",
#               "payload": {
#                 "document_id": "test.jpg_chunk_0",
#                 "type": "images",
#                 "text": "NO_TEXT_FOUND",
#                 "filename": "test.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 13,
#                 "upload_time": "2025-10-28T09:02:27.336838+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/test",
#                 "version_id": "9690223a3678339b984027ba7f7c511b207d700bb0a284fa091c392e6abd38be",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.47484303,
#               "id": "fe8925d6-7e02-4cbd-8730-ad87ee105185",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_18",
#                 "text": "這裏他提示規範已經創建成功這裏是這個文件存放的路徑這裏是總結在這裏就是具體的功能下面是三個需要澄清的地方包括使用期間的通話行爲是暫停還是放棄還有設備日期時間的操作處理還有繪畫在午夜完成應該統計哪天的數據",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 18,
#                 "start_time": "407.798",
#                 "end_time": "427.88",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.43846,
#               "id": "ff718285-56b8-491b-9348-1a308ef69ab0",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_14",
#                 "text": "因爲我要開發一款原生的iOS番茄專注app所以我這裏就輸入對應的提示詞我輸入的提示詞是保持iOS forest風格的專注應用要求極致簡潔並支持離線優先強制執行測試驅動開發60fps動畫小於兩秒的冷啓動並且支持voice over dynamic type我們直接運行先看一下這個效果這裏開始運行這樣他就會創建這個項目的原則和開發規範",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 14,
#                 "start_time": "308.337",
#                 "end_time": "337.649",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.43139476,
#               "id": "efba631e-6231-4857-9b02-c20d3d472215",
#               "payload": {
#                 "audio_id": "AI02_chunk_1",
#                 "text": "03就在這裏,有近140IQ,太厲害了01 Pro有120IQ,01 baseline有90IQ",
#                 "filename": "AI02.wav",
#                 "chunk_index": 1,
#                 "start_time": "22.593",
#                 "end_time": "35.08",
#                 "speaker": "SPEAKER_00",
#                 "type": "audios",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T09:01:16.245913+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/AI02",
#                 "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.41946447,
#               "id": "af882964-90ef-4882-8b44-4a6cd4f59555",
#               "payload": {
#                 "audio_id": "YTtest2_chunk_0",
#                 "text": "哈囉大家好我是顏仁烈今天要講的動漫是進擊的巨人",
#                 "filename": "YTtest2.wav",
#                 "chunk_index": 0,
#                 "start_time": "11.692",
#                 "end_time": "15.657",
#                 "speaker": "SPEAKER_00",
#                 "type": "audios",
#                 "audio_labels": [],
#                 "upload_time": "2025-10-27T10:14:15.245030+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/YTtest2",
#                 "version_id": "9314c1539edc0e84016d9f63fcd957131c5d61bc205fa06e252848e90d320962",
#                 "status": "active"
#               }
#             }
#           ],
#           "stats": {
#             "video": {
#               "count": 2,
#               "avg_score": 0.456651515
#             },
#             "audio": {
#               "count": 2,
#               "avg_score": 0.425429615
#             },
#             "document": {
#               "count": 2,
#               "avg_score": 0.49348626
#             },
#             "image": {
#               "count": 2,
#               "avg_score": 0.48317567
#             }
#           },
#           "query": "請根據這些搜尋結果總結重點",
#           "original_user_query": "請根據這些搜尋結果總結重點"
#         }
#       ]
#     },
#     {
#       "timestamp": 1763097124.7241209,
#       "user_message": "請根據這些搜尋結果總結重點",
#       "assistant_response": "根據搜尋結果，最相關的文件是一個PDF文件（9708.pdf），內容涉及到對某些句子進行錯誤修訂和填空測試。以下是該文件的一些重點：\n\n1. **錯誤修訂**：\n   - 這部分的內容包括對一些不正確的詞語或短語進行修改，例如：\n     ```\n     This chapter compares and contrasts the politic use and impact of quotas on (A) practices in the latter half of the twentieth century hiring.\n     Oftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs.\n     if a couple months left init; 4 got\n     There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n     If he can stay out bx her friends until midnight, why can't (A).\n     I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n     ```\n   - 這些句子中有多個錯誤需要修正。\n\n2. **填空測試**：\n   - 文件中的CLOZE TEST部分要求讀者選擇適當的單詞來填充空白，例如：\n     ```\n     Researchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders, since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very.\n     Still , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26).\n     ```\n   - 這些空白需要填充適當的詞語。\n\n3. **討論**：\n   - 文件還包括對某些研究結果的討論，例如：\n     ```\n     Dr. Peterson noted, \"This is all very strong evidence; and avery good set of leads, but we can't (27) say that we have proved the involvement of these regions in autism.\"\n     ```\n\n根據上述內容，這個PDF文件主要涉及到語言錯誤的修訂和填空測試，並包括一些與自閉症相關研究的討論。",
#       "search_results": [
#         {
#           "collection": "unified",
#           "items": [
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.49348626,
#               "id": "e9f74d52-7829-408a-8774-76316354e5a2",
#               "payload": {
#                 "document_id": "96008_chunk_2",
#                 "type": "documents",
#                 "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#                 "filename": "96008.pdf",
#                 "source": "pdf",
#                 "chunk_index": 2,
#                 "page_numbers": [
#                   2,
#                   3
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 1512,
#                 "upload_time": "2025-11-06T18:25:40.229136",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/96008",
#                 "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "document",
#               "collection": "document",
#               "score": 0.49348626,
#               "id": "959393be-158e-482c-a0ac-c46528d9d3bc",
#               "payload": {
#                 "document_id": "96008_chunk_2",
#                 "type": "documents",
#                 "text": "(A) feline (B) canine (C) fish\n\nERROR RECOGNITION\n\nInstructions: Identify the one underlined word or phrase that should be changed for the sentence to be correct.\n\nThis chapter compares and contrasts the politic use and impact of quotas on (A practices in the latter half of the twentieth century hiring\n\nOftentimes, it's difficult to know whether a copy machine is on its last Or (A) legs\n\nif a couple months left init; 4 got\n\n21 . There are way few jobs in banking the moment that you're not really in a 8) position to pick and choose. (A)\n\nIf he can stay out bx her friends until midnight, why can't (A\n\n23 . I won't name names, but their are some people in_ room have broken (A) '43 several of the club's rules.\n\nCLOZE TEST Instructions: Choose the best answer to fìll in the following blanks.\n\nResearchers today reported their most recent findings on autism. said that genes that effect early neural growth could be key to autistic disorders , since \"the genetic and the non-genetic (24) to autism; by definition; have to exert their effect early in brain development; either in utero or in the first months or couple of years of life They very\n\n8\n\n3\n\nStill , (25) that the new study only points to potential leads for future research. Because of the study's particular methodology; no one finding reached statistical (26) Dr. Peterson noted , \"This is all very strong evidence; and avery good set of leads, but we can't (27 say that we have proved the involvement of these regions in autism; ' he said they",
#                 "filename": "96008.pdf",
#                 "source": "pdf",
#                 "chunk_index": 2,
#                 "page_numbers": [
#                   2,
#                   3
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 1512,
#                 "upload_time": "2025-11-06T18:25:23.298399",
#                 "embedding_type": "text",
#                 "asset_path": "document/pdf/96008",
#                 "version_id": "5ca5fe1af3406f933928f92d2d95afd53740e278eaa6ab7890889275e615b1f4",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.4833184,
#               "id": "c9a5dd64-797b-45f3-b410-aa646cea45b8",
#               "payload": {
#                 "document_id": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg_chunk_0",
#                 "type": "images",
#                 "text": "VALLENTINE 45\nWILLIAMS 44\nPRITCHARD 11\n ups\nNCAAM\nNCAAM\n\nNO其他文字需要提取",
#                 "filename": "Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 67,
#                 "upload_time": "2025-10-31T03:15:50.698020+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/Cleveland_Cavaliers_vs._Boston_Celtics__51688485310_",
#                 "version_id": "378787f28e90ac6dae5e7dedbcfaee4965d5e053f6a247acdb208f4f0c35f63b",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "image",
#               "collection": "image",
#               "score": 0.48303294,
#               "id": "b798dbfe-8782-4a90-948a-272dac5709dd",
#               "payload": {
#                 "document_id": "test.jpg_chunk_0",
#                 "type": "images",
#                 "text": "NO_TEXT_FOUND",
#                 "filename": "test.jpg",
#                 "source": "jpg",
#                 "chunk_index": 0,
#                 "page_numbers": [
#                   1
#                 ],
#                 "element_types": [
#                   "text"
#                 ],
#                 "char_count": 13,
#                 "upload_time": "2025-10-28T09:02:27.336838+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "image/jpg/test",
#                 "version_id": "9690223a3678339b984027ba7f7c511b207d700bb0a284fa091c392e6abd38be",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.47484303,
#               "id": "fe8925d6-7e02-4cbd-8730-ad87ee105185",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_18",
#                 "text": "這裏他提示規範已經創建成功這裏是這個文件存放的路徑這裏是總結在這裏就是具體的功能下面是三個需要澄清的地方包括使用期間的通話行爲是暫停還是放棄還有設備日期時間的操作處理還有繪畫在午夜完成應該統計哪天的數據",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 18,
#                 "start_time": "407.798",
#                 "end_time": "427.88",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "video",
#               "collection": "video",
#               "score": 0.43846,
#               "id": "ff718285-56b8-491b-9348-1a308ef69ab0",
#               "payload": {
#                 "audio_id": "YTtest1.mp4_chunk_14",
#                 "text": "因爲我要開發一款原生的iOS番茄專注app所以我這裏就輸入對應的提示詞我輸入的提示詞是保持iOS forest風格的專注應用要求極致簡潔並支持離線優先強制執行測試驅動開發60fps動畫小於兩秒的冷啓動並且支持voice over dynamic type我們直接運行先看一下這個效果這裏開始運行這樣他就會創建這個項目的原則和開發規範",
#                 "filename": "YTtest1.mp4",
#                 "chunk_index": 14,
#                 "start_time": "308.337",
#                 "end_time": "337.649",
#                 "speaker": "SPEAKER_00",
#                 "type": "videos",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T18:26:45.827703",
#                 "embedding_type": "text",
#                 "asset_path": "video/mp4/YTtest1",
#                 "version_id": "de138d63231f2ad0442691eae305938450eda88dbd98abcc4ecf653b128b6043",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.43139476,
#               "id": "efba631e-6231-4857-9b02-c20d3d472215",
#               "payload": {
#                 "audio_id": "AI02_chunk_1",
#                 "text": "03就在這裏,有近140IQ,太厲害了01 Pro有120IQ,01 baseline有90IQ",
#                 "filename": "AI02.wav",
#                 "chunk_index": 1,
#                 "start_time": "22.593",
#                 "end_time": "35.08",
#                 "speaker": "SPEAKER_00",
#                 "type": "audios",
#                 "audio_labels": [
#                   "Speech"
#                 ],
#                 "upload_time": "2025-10-27T09:01:16.245913+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/AI02",
#                 "version_id": "805b1f2d66748920b81ad155b10a2bf1ccf3bd4bf0e2d52cbbe892c3e051efc9",
#                 "status": "active"
#               }
#             },
#             {
#               "type": "audio",
#               "collection": "audio",
#               "score": 0.41946447,
#               "id": "af882964-90ef-4882-8b44-4a6cd4f59555",
#               "payload": {
#                 "audio_id": "YTtest2_chunk_0",
#                 "text": "哈囉大家好我是顏仁烈今天要講的動漫是進擊的巨人",
#                 "filename": "YTtest2.wav",
#                 "chunk_index": 0,
#                 "start_time": "11.692",
#                 "end_time": "15.657",
#                 "speaker": "SPEAKER_00",
#                 "type": "audios",
#                 "audio_labels": [],
#                 "upload_time": "2025-10-27T10:14:15.245030+00:00",
#                 "embedding_type": "text",
#                 "asset_path": "audio/x-wav/YTtest2",
#                 "version_id": "9314c1539edc0e84016d9f63fcd957131c5d61bc205fa06e252848e90d320962",
#                 "status": "active"
#               }
#             }
#           ],
#           "stats": {
#             "video": {
#               "count": 2,
#               "avg_score": 0.456651515
#             },
#             "audio": {
#               "count": 2,
#               "avg_score": 0.425429615
#             },
#             "document": {
#               "count": 2,
#               "avg_score": 0.49348626
#             },
#             "image": {
#               "count": 2,
#               "avg_score": 0.48317567
#             }
#           },
#           "query": "請根據這些搜尋結果總結重點",
#           "original_user_query": "請根據這些搜尋結果總結重點"
#         }
#       ]
#     }
#   ]
# }

# %%
# Clear chat memory (currently cannot clear)
try:
    result = client.clear_chat_memory(user_id="test_user1")
    print("✓ Chat memory cleared")
except Exception as e:
    print(f"清除Failed: {e}")
# Out:
# 清除失敗: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## 9. Health Check

# %%
# API Health Check
try:
    health = client.health_check()
    print("API health status:")
    print(json.dumps(health, indent=2, ensure_ascii=False))
except Exception as e:
    print(f"Health CheckFailed: {e}")
# Out:
# API 健康狀態:
# {
#   "status": "ok"
# }

# %% [markdown]
# ## Summary
#
# 本 Notebook 展示了 RAPTOR API Gateway 的所有主要功能：
#
# - ✅ 認證（註冊、登入）
# - ✅ 搜尋（影片、音訊、文件、圖片、統一搜尋）
# - ✅ File Upload（單檔、批次、自動分析）
# - ✅ Asset Management（版本、下載、封存、刪除）
# - ✅ Data Processing (Process Files, Cache Queries)
# - ✅ Chat Features（對話、記憶管理）
# - ✅ Health Check
#
# ## 相關資源
#
# - **API Documentation**: http://raptor_open_0_1_api.dhtsolution.com:8012/docs
# - **README**: 參考專案中的 README.md
# - **詳細指南**: 參考 SAMPLE_CODE_GUIDE.md
#
# ## Note事項
#
# 1. **認證**: 大部分 API 需要先Login to Get Token
# 2. **檔案路徑**: 上傳功能需要實際的檔案路徑
# 3. **並行限制**: 批次上傳的 concurrency 範圍為 1-16
# 4. **搜尋限制**:
#    - 每個集合最多返回 50 個結果
#    - 統一搜尋最多返回 100 個Summary果
# 5. **TTL**: archive_ttl 和 destroy_ttl 的單位為天
